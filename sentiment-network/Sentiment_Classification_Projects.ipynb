# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
# print(type(reviews))
for k,review in enumerate(reviews):
    for word in review.split(' '):
        if labels[k] == 'POSITIVE':
            positive_counts[word] += 1
        else:
            negative_counts[word] += 1
        total_counts[word] += 1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 1101081),
#  ('the', 346705),
#  ('.', 319371),
#  ('and', 179459),
#  ('a', 167414),
#  ('of', 153728),
#  ('to', 133526),
#  ('is', 114508),
#  ('in', 100441),
#  ('br', 98478),
#  ('it', 96064),
#  ('i', 81496),
#  ('that', 71271),
#  ('this', 70166),
#  ('s', 67639),
#  ('as', 52628),
#  ('with', 46498),
#  ('for', 44838),
#  ('was', 43838),
#  ('film', 41878),
#  ('but', 41650),
#  ('movie', 38151),
#  ('his', 34462),
#  ('on', 34028),
#  ('you', 33367),
#  ('he', 32572),
#  ('are', 29618),
#  ('not', 28551),
#  ('t', 27445),
#  ('one', 27313),
#  ('have', 25178),
#  ('be', 24836),
#  ('by', 23997),
#  ('all', 23889),
#  ('who', 22936),
#  ('an', 22590),
#  ('at', 22470),
#  ('from', 21537),
#  ('her', 20950),
#  ('they', 19794),
#  ('has', 18374),
#  ('so', 18310),
#  ('like', 18081),
#  ('about', 16629),
#  ('very', 16611),
#  ('out', 16270),
#  ('there', 16115),
#  ('she', 15559),
#  ('what', 15480),
#  ('or', 15473),
#  ('good', 15443),
#  ('more', 15045),
#  ('when', 14915),
#  ('some', 14886),
#  ('if', 14574),
#  ('just', 14305),
#  ('can', 14006),
#  ('story', 13561),
#  ('time', 13033),
#  ('my', 12979),
#  ('great', 12838),
#  ('well', 12811),
#  ('up', 12643),
#  ('which', 12536),
#  ('their', 12218),
#  ('see', 12057),
#  ('also', 11101),
#  ('we', 11062),
#  ('really', 10952),
#  ('would', 10800),
#  ('will', 10437),
#  ('me', 10336),
#  ('had', 10298),
#  ('only', 10275),
#  ('him', 10036),
#  ('even', 9928),
#  ('most', 9732),
#  ('other', 9719),
#  ('were', 9567),
#  ('first', 9510),
#  ('than', 9475),
#  ('much', 9373),
#  ('its', 9247),
#  ('no', 9148),
#  ('into', 9088),
#  ('people', 8960),
#  ('best', 8640),
#  ('love', 8605),
#  ('get', 8544),
#  ('how', 8427),
#  ('life', 8400),
#  ('been', 8381),
#  ('because', 8158),
#  ('way', 8073),
#  ('do', 7886),
#  ('made', 7647),
#  ('films', 7627),
#  ('them', 7610),
#  ('after', 7602),
#  ('many', 7535),
#  ('two', 7467),
#  ('too', 7319),
#  ('think', 7312),
#  ('movies', 7173),
#  ('characters', 7121),
#  ('character', 7029),
#  ('don', 6937),
#  ('man', 6921),
#  ('show', 6866),
#  ('watch', 6848),
#  ('seen', 6829),
#  ('then', 6716),
#  ('little', 6682),
#  ('still', 6681),
#  ('make', 6608),
#  ('could', 6476),
#  ('never', 6453),
#  ('being', 6439),
#  ('where', 6352),
#  ('does', 6139),
#  ('over', 6035),
#  ('any', 6004),
#  ('while', 5800),
#  ('know', 5667),
#  ('did', 5583),
#  ('years', 5518),
#  ('here', 5482),
#  ('ever', 5469),
#  ('end', 5393),
#  ('these', 5388),
#  ('such', 5184),
#  ('scene', 5137),
#  ('real', 5136),
#  ('back', 5094),
#  ('those', 4971),
#  ('though', 4950),
#  ('off', 4928),
#  ('new', 4916),
#  ('your', 4907),
#  ('go', 4880),
#  ('acting', 4876),
#  ('plot', 4866),
#  ('world', 4859),
#  ('scenes', 4856),
#  ('say', 4829),
#  ('through', 4819),
#  ('makes', 4780),
#  ('better', 4763),
#  ('now', 4736),
#  ('work', 4694),
#  ('young', 4687),
#  ('old', 4622),
#  ('ve', 4614),
#  ('find', 4544),
#  ('both', 4497),
#  ('before', 4356),
#  ('us', 4324),
#  ('again', 4317),
#  ('series', 4306),
#  ('quite', 4287),
#  ('something', 4271),
#  ('cast', 4267),
#  ('should', 4244),
#  ('part', 4196),
#  ('always', 4176),
#  ('lot', 4174),
#  ('another', 4150),
#  ('actors', 4094),
#  ('director', 4081),
#  ('family', 4064),
#  ('between', 4033),
#  ('own', 4032),
#  ('m', 3998),
#  ('may', 3994),
#  ('same', 3945),
#  ('role', 3934),
#  ('watching', 3932),
#  ('every', 3909),
#  ('funny', 3907),
#  ('doesn', 3870),
#  ('performance', 3856),
#  ('few', 3836),
#  ('bad', 3814),
#  ('look', 3801),
#  ('re', 3769),
#  ('why', 3710),
#  ('things', 3699),
#  ('times', 3664),
#  ('big', 3631),
#  ('however', 3590),
#  ('actually', 3581),
#  ('action', 3578),
#  ('going', 3567),
#  ('bit', 3515),
#  ('comedy', 3486),
#  ('down', 3481),
#  ('music', 3476),
#  ('must', 3456),
#  ('take', 3419),
#  ('saw', 3385),
#  ('long', 3380),
#  ('right', 3377),
#  ('fun', 3372),
#  ('fact', 3368),
#  ('excellent', 3366),
#  ('around', 3348),
#  ('without', 3345),
#  ('didn', 3344),
#  ('thing', 3324),
#  ('thought', 3278),
#  ('got', 3271),
#  ('each', 3261),
#  ('day', 3229),
#  ('feel', 3194),
#  ('seems', 3192),
#  ('come', 3188),
#  ('done', 3172),
#  ('beautiful', 3160),
#  ('especially', 3144),
#  ('played', 3143),
#  ('almost', 3132),
#  ('want', 3124),
#  ('yet', 3112),
#  ('give', 3108),
#  ('pretty', 3098),
#  ('last', 3086),
#  ('since', 3038),
#  ('different', 3008),
#  ('although', 3002),
#  ('gets', 2981),
#  ('true', 2974),
#  ('interesting', 2962),
#  ('job', 2941),
#  ('enough', 2910),
#  ('our', 2908),
#  ('shows', 2895),
#  ('horror', 2882),
#  ('woman', 2879),
#  ('tv', 2800),
#  ('probably', 2797),
#  ('father', 2790),
#  ('original', 2786),
#  ('girl', 2780),
#  ('point', 2758),
#  ('plays', 2757),
#  ('wonderful', 2744),
#  ('far', 2717),
#  ('course', 2716),
#  ('john', 2700),
#  ('rather', 2680),
#  ('isn', 2658),
#  ('ll', 2653),
#  ('later', 2649),
#  ('dvd', 2648),
#  ('whole', 2621),
#  ('war', 2621),
#  ('d', 2614),
#  ('found', 2613),
#  ('away', 2612),
#  ('screen', 2610),
#  ('nothing', 2600),
#  ('once', 2596),
#  ('year', 2594),
#  ('hard', 2588),
#  ('together', 2560),
#  ('set', 2554),
#  ('am', 2554),
#  ('having', 2533),
#  ('making', 2532),
#  ('place', 2526),
#  ('might', 2520),
#  ('comes', 2520),
#  ('sure', 2507),
#  ('american', 2496),
#  ('play', 2490),
#  ('kind', 2488),
#  ('perfect', 2484),
#  ('takes', 2484),
#  ('performances', 2474),
#  ('himself', 2461),
#  ('worth', 2443),
#  ('everyone', 2442),
#  ('anyone', 2428),
#  ('actor', 2407),
#  ('three', 2403),
#  ('wife', 2392),
#  ('classic', 2386),
#  ('goes', 2372),
#  ('ending', 2356),
#  ('version', 2336),
#  ('star', 2298),
#  ('enjoy', 2292),
#  ('book', 2284),
#  ('nice', 2264),
#  ('everything', 2259),
#  ('during', 2248),
#  ('put', 2236),
#  ('seeing', 2222),
#  ('least', 2204),
#  ('house', 2200),
#  ('high', 2195),
#  ('watched', 2188),
#  ('loved', 2174),
#  ('men', 2174),
#  ('night', 2164),
#  ('anything', 2151),
#  ('believe', 2143),
#  ('guy', 2142),
#  ('top', 2126),
#  ('amazing', 2116),
#  ('hollywood', 2112),
#  ('looking', 2106),
#  ('main', 2088),
#  ('definitely', 2086),
#  ('gives', 2062),
#  ('home', 2060),
#  ('seem', 2056),
#  ('episode', 2047),
#  ('audience', 2041),
#  ('sense', 2040),
#  ('truly', 2035),
#  ('special', 2022),
#  ('second', 2019),
#  ('short', 2018),
#  ('fan', 2018),
#  ('mind', 2010),
#  ('human', 2003),
#  ('recommend', 1998),
#  ('full', 1992),
#  ('black', 1990),
#  ('help', 1984),
#  ('along', 1978),
#  ('trying', 1974),
#  ('small', 1972),
#  ('death', 1970),
#  ('friends', 1962),
#  ('remember', 1948),
#  ('often', 1941),
#  ('said', 1932),
#  ('favorite', 1925),
#  ('heart', 1918),
#  ('early', 1914),
#  ('left', 1912),
#  ('until', 1911),
#  ('script', 1908),
#  ('let', 1908),
#  ('maybe', 1876),
#  ('today', 1872),
#  ('live', 1870),
#  ('less', 1869),
#  ('moments', 1867),
#  ('others', 1859),
#  ('brilliant', 1853),
#  ('shot', 1850),
#  ('liked', 1846),
#  ('become', 1832),
#  ('won', 1830),
#  ('used', 1822),
#  ('style', 1814),
#  ('mother', 1790),
#  ('lives', 1788),
#  ('came', 1786),
#  ('stars', 1781),
#  ('cinema', 1778),
#  ('looks', 1770),
#  ('perhaps', 1768),
#  ('read', 1764),
#  ('enjoyed', 1758),
#  ('boy', 1750),
#  ('drama', 1746),
#  ('given', 1742),
#  ('highly', 1742),
#  ('playing', 1734),
#  ('use', 1728),
#  ('next', 1720),
#  ('women', 1716),
#  ('fine', 1714),
#  ('effects', 1712),
#  ('kids', 1709),
#  ('entertaining', 1706),
#  ('need', 1704),
#  ('line', 1701),
#  ('works', 1696),
#  ('someone', 1695),
#  ('mr', 1672),
#  ('simply', 1670),
#  ('picture', 1666),
#  ('children', 1666),
#  ('face', 1663),
#  ('keep', 1662),
#  ('friend', 1662),
#  ('dark', 1660),
#  ('overall', 1657),
#  ('certainly', 1656),
#  ('minutes', 1654),
#  ('wasn', 1649),
#  ('history', 1644),
#  ('finally', 1640),
#  ('couple', 1632),
#  ('against', 1630),
#  ('son', 1618),
#  ('understand', 1616),
#  ('lost', 1615),
#  ('michael', 1610),
#  ('else', 1603),
#  ('throughout', 1596),
#  ('fans', 1594),
#  ('city', 1584),
#  ('reason', 1578),
#  ('written', 1575),
#  ('production', 1574),
#  ('school', 1569),
#  ('several', 1568),
#  ('based', 1562),
#  ('rest', 1562),
#  ('try', 1560),
#  ('dead', 1552),
#  ('hope', 1550),
#  ('strong', 1536),
#  ('white', 1530),
#  ('tell', 1518),
#  ('itself', 1516),
#  ('half', 1506),
#  ('person', 1498),
#  ('sometimes', 1492),
#  ('past', 1488),
#  ('start', 1488),
#  ('genre', 1486),
#  ('beginning', 1478),
#  ('final', 1478),
#  ('town', 1476),
#  ('art', 1468),
#  ('humor', 1464),
#  ('game', 1464),
#  ('yes', 1462),
#  ('idea', 1462),
#  ('late', 1460),
#  ('becomes', 1458),
#  ('despite', 1458),
#  ('able', 1452),
#  ('case', 1452),
#  ('money', 1448),
#  ('child', 1442),
#  ('completely', 1442),
#  ('side', 1439),
#  ('camera', 1432),
#  ('getting', 1428),
#  ('instead', 1425),
#  ('soon', 1404),
#  ('under', 1401),
#  ('viewer', 1398),
#  ('age', 1395),
#  ('days', 1393),
#  ('stories', 1392),
#  ('felt', 1388),
#  ('simple', 1388),
#  ('roles', 1386),
#  ('video', 1376),
#  ('name', 1367),
#  ('either', 1367),
#  ('doing', 1354),
#  ('turns', 1348),
#  ('wants', 1344),
#  ('close', 1342),
#  ('title', 1338),
#  ('wrong', 1336),
#  ('went', 1332),
#  ('james', 1330),
#  ('evil', 1318),
#  ('budget', 1314),
#  ('episodes', 1314),
#  ('relationship', 1310),
#  ('fantastic', 1308),
#  ('piece', 1306),
#  ('david', 1302),
#  ('turn', 1296),
#  ('murder', 1292),
#  ('parts', 1291),
#  ('brother', 1288),
#  ('absolutely', 1286),
#  ('head', 1286),
#  ('experience', 1284),
#  ('eyes', 1282),
#  ('sex', 1276),
#  ('direction', 1274),
#  ('called', 1274),
#  ('directed', 1272),
#  ('lines', 1268),
#  ('behind', 1266),
#  ('sort', 1264),
#  ('lead', 1263),
#  ('actress', 1263),
#  ('oscar', 1256),
#  ('including', 1255),
#  ('example', 1254),
#  ('known', 1250),
#  ('musical', 1250),
#  ('chance', 1242),
#  ('score', 1240),
#  ('already', 1239),
#  ('feeling', 1238),
#  ('hit', 1238),
#  ('voice', 1230),
#  ('moment', 1224),
#  ('living', 1224),
#  ('low', 1220),
#  ('supporting', 1220),
#  ('ago', 1218),
#  ('themselves', 1216),
#  ('reality', 1211),
#  ('hilarious', 1210),
#  ('jack', 1208),
#  ('told', 1206),
#  ('hand', 1203),
#  ('quality', 1200),
#  ('moving', 1200),
#  ('dialogue', 1200),
#  ('matter', 1198),
#  ('song', 1198),
#  ('happy', 1198),
#  ('paul', 1196),
#  ('light', 1188),
#  ('future', 1187),
#  ('entire', 1184),
#  ('finds', 1182),
#  ('gave', 1180),
#  ('laugh', 1174),
#  ('released', 1172),
#  ('expect', 1169),
#  ('fight', 1163),
#  ('particularly', 1160),
#  ('cinematography', 1158),
#  ('police', 1158),
#  ('whose', 1156),
#  ('type', 1156),
#  ('sound', 1156),
#  ('view', 1149),
#  ('enjoyable', 1146),
#  ('number', 1144),
#  ('romantic', 1144),
#  ('husband', 1144),
#  ('daughter', 1144),
#  ('documentary', 1142),
#  ('self', 1140),
#  ('superb', 1139),
#  ('modern', 1138),
#  ('took', 1138),
#  ('robert', 1138),
#  ('mean', 1132),
#  ('shown', 1126),
#  ('coming', 1122),
#  ('important', 1120),
#  ('king', 1119),
#  ('leave', 1118),
#  ('change', 1116),
#  ('somewhat', 1110),
#  ('wanted', 1110),
#  ('tells', 1108),
#  ('events', 1104),
#  ('run', 1104),
#  ('career', 1104),
#  ('country', 1104),
#  ('heard', 1100),
#  ('season', 1100),
#  ('greatest', 1098),
#  ('girls', 1098),
#  ('etc', 1094),
#  ('care', 1092),
#  ('starts', 1090),
#  ('english', 1084),
#  ('killer', 1082),
#  ('tale', 1080),
#  ('guys', 1080),
#  ('totally', 1080),
#  ('animation', 1080),
#  ('usual', 1079),
#  ('miss', 1070),
#  ('opinion', 1070),
#  ('easy', 1062),
#  ('violence', 1062),
#  ('songs', 1060),
#  ('british', 1056),
#  ('says', 1053),
#  ('realistic', 1053),
#  ('writing', 1048),
#  ('writer', 1045),
#  ('act', 1044),
#  ('comic', 1042),
#  ('thriller', 1038),
#  ('television', 1034),
#  ('power', 1032),
#  ('ones', 1030),
#  ('kid', 1028),
#  ('york', 1026),
#  ('novel', 1026),
#  ('alone', 1024),
#  ('problem', 1024),
#  ('attention', 1018),
#  ('involved', 1016),
#  ('kill', 1015),
#  ('extremely', 1014),
#  ('seemed', 1012),
#  ('hero', 1010),
#  ('french', 1010),
#  ('rock', 1008),
#  ('stuff', 1002),
#  ('wish', 998),
#  ('begins', 996),
#  ('taken', 994),
#  ('sad', 994),
#  ('ways', 992),
#  ('richard', 990),
#  ('knows', 988),
#  ('atmosphere', 986),
#  ('similar', 982),
#  ('surprised', 982),
#  ('taking', 982),
#  ('car', 982),
#  ('george', 981),
#  ('perfectly', 980),
#  ('across', 978),
#  ('team', 978),
#  ('eye', 978),
#  ('sequence', 978),
#  ('room', 977),
#  ('due', 976),
#  ('among', 976),
#  ('serious', 976),
#  ('powerful', 976),
#  ('strange', 974),
#  ('order', 974),
#  ('cannot', 974),
#  ('b', 974),
#  ('beauty', 972),
#  ('famous', 970),
#  ('happened', 968),
#  ('tries', 968),
#  ('herself', 968),
#  ('myself', 968),
#  ('class', 966),
#  ('four', 964),
#  ('cool', 962),
#  ('release', 958),
#  ('anyway', 958),
#  ('theme', 958),
#  ('opening', 956),
#  ('entertainment', 955),
#  ('slow', 950),
#  ('ends', 950),
#  ('unique', 950),
#  ('exactly', 950),
#  ('easily', 949),
#  ('level', 948),
#  ('o', 948),
#  ('red', 948),
#  ('interest', 944),
#  ('happen', 942),
#  ('crime', 940),
#  ('viewing', 936),
#  ('sets', 935),
#  ('memorable', 934),
#  ('stop', 932),
#  ('group', 932),
#  ('problems', 926),
#  ('dance', 926),
#  ('working', 926),
#  ('sister', 926),
#  ('message', 926),
#  ('knew', 925),
#  ('mystery', 922),
#  ('nature', 922),
#  ('bring', 920),
#  ('believable', 918),
#  ('thinking', 918),
#  ('brought', 918),
#  ('mostly', 916),
#  ('disney', 914),
#  ('couldn', 914),
#  ('society', 913),
#  ('lady', 911),
#  ('within', 910),
#  ('blood', 908),
#  ('parents', 906),
#  ('upon', 906),
#  ('viewers', 906),
#  ('meets', 905),
#  ('form', 904),
#  ('peter', 904),
#  ('tom', 904),
#  ('usually', 904),
#  ('soundtrack', 904),
#  ('local', 900),
#  ('certain', 896),
#  ('follow', 896),
#  ('whether', 894),
#  ('possible', 892),
#  ('emotional', 890),
#  ('killed', 889),
#  ('above', 888),
#  ('de', 888),
#  ('god', 886),
#  ('middle', 886),
#  ('needs', 884),
#  ('happens', 884),
#  ('flick', 884),
#  ('masterpiece', 882),
#  ('period', 880),
#  ('major', 880),
#  ('named', 878),
#  ('haven', 878),
#  ('particular', 876),
#  ('th', 876),
#  ('earth', 874),
#  ('feature', 874),
#  ('stand', 872),
#  ('words', 871),
#  ('typical', 871),
#  ('elements', 866),
#  ('obviously', 866),
#  ('romance', 862),
#  ('jane', 860),
#  ('yourself', 854),
#  ('showing', 854),
#  ('brings', 852),
#  ('fantasy', 852),
#  ('guess', 846),
#  ('america', 846),
#  ('unfortunately', 844),
#  ('huge', 844),
#  ('indeed', 842),
#  ('running', 842),
#  ('talent', 840),
#  ('stage', 838),
#  ('started', 836),
#  ('leads', 834),
#  ('sweet', 834),
#  ('japanese', 834),
#  ('poor', 832),
#  ('deal', 832),
#  ('incredible', 826),
#  ('personal', 826),
#  ('fast', 824),
#  ('became', 820),
#  ('deep', 820),
#  ('hours', 818),
#  ('giving', 816),
#  ('nearly', 816),
#  ('dream', 816),
#  ('clearly', 814),
#  ('turned', 814),
#  ('obvious', 812),
#  ('near', 812),
#  ('cut', 811),
#  ('surprise', 810),
#  ('era', 808),
#  ('body', 808),
#  ('hour', 806),
#  ('female', 806),
#  ('five', 806),
#  ('note', 798),
#  ('learn', 796),
#  ('truth', 796),
#  ('except', 794),
#  ('feels', 794),
#  ('match', 794),
#  ('tony', 794),
#  ('street', 788),
#  ('filmed', 788),
#  ('clear', 788),
#  ('complete', 788),
#  ('eventually', 786),
#  ('keeps', 786),
#  ('older', 786),
#  ('lots', 786),
#  ('buy', 784),
#  ('william', 782),
#  ('stewart', 782),
#  ('fall', 781),
#  ('joe', 780),
#  ('meet', 780),
#  ('unlike', 779),
#  ('talking', 778),
#  ('shots', 778),
#  ('rating', 778),
#  ('difficult', 778),
#  ('dramatic', 777),
#  ('means', 776),
#  ('situation', 773),
#  ('wonder', 772),
#  ('present', 772),
#  ('appears', 772),
#  ('subject', 772),
#  ('comments', 770),
#  ('general', 766),
#  ('sequences', 766),
#  ('lee', 766),
#  ('points', 764),
#  ('earlier', 764),
#  ('gone', 758),
#  ('check', 758),
#  ('suspense', 756),
#  ('recommended', 756),
#  ('ten', 756),
#  ('third', 754),
#  ('business', 754),
#  ('talk', 750),
#  ('leaves', 750),
#  ('beyond', 750),
#  ('portrayal', 748),
#  ('beautifully', 746),
#  ('single', 744),
#  ('bill', 744),
#  ('plenty', 742),
#  ('word', 742),
#  ('whom', 740),
#  ('falls', 740),
#  ('scary', 738),
#  ('non', 738),
#  ('figure', 738),
#  ('battle', 738),
#  ('using', 737),
#  ('return', 736),
#  ('doubt', 734),
#  ('add', 734),
#  ('hear', 732),
#  ('solid', 732),
#  ('success', 732),
#  ('jokes', 731),
#  ('oh', 730),
#  ('touching', 730),
#  ('political', 730),
#  ('hell', 728),
#  ('awesome', 728),
#  ('boys', 728),
#  ('sexual', 724),
#  ('recently', 724),
#  ('dog', 724),
#  ('please', 722),
#  ('wouldn', 722),
#  ('straight', 722),
#  ('features', 722),
#  ('forget', 720),
#  ('setting', 720),
#  ('lack', 720),
#  ('married', 718),
#  ('mark', 718),
#  ('social', 714),
#  ('interested', 712),
#  ('adventure', 712),
#  ('actual', 710),
#  ('terrific', 710),
#  ('sees', 710),
#  ('brothers', 710),
#  ('move', 709),
#  ('call', 708),
#  ('various', 706),
#  ('theater', 706),
#  ('dr', 706),
#  ('animated', 704),
#  ('western', 702),
#  ('baby', 700),
#  ('space', 700),
#  ('leading', 696),
#  ('disappointed', 696),
#  ('portrayed', 692),
#  ('aren', 692),
#  ('screenplay', 690),
#  ('smith', 690),
#  ('towards', 688),
#  ('hate', 688),
#  ('noir', 686),
#  ('outstanding', 684),
#  ('decent', 684),
#  ('kelly', 684),
#  ('directors', 682),
#  ('journey', 682),
#  ('none', 681),
#  ('looked', 680),
#  ('effective', 680),
#  ('rich', 679),
#  ('storyline', 678),
#  ('caught', 678),
#  ('sci', 678),
#  ('fi', 678),
#  ('cold', 678),
#  ('mary', 678),
#  ('charming', 676),
#  ('popular', 674),
#  ('rare', 674),
#  ('manages', 674),
#  ('harry', 674),
#  ('spirit', 672),
#  ('appreciate', 670),
#  ('open', 670),
#  ('moves', 668),
#  ('basically', 668),
#  ('acted', 668),
#  ('inside', 666),
#  ('boring', 666),
#  ('century', 666),
#  ('mention', 666),
#  ('deserves', 666),
#  ('subtle', 666),
#  ('pace', 666),
#  ('familiar', 664),
#  ('background', 664),
#  ('ben', 662),
#  ('creepy', 660),
#  ('supposed', 660),
#  ('secret', 658),
#  ('die', 656),
#  ('jim', 656),
#  ('question', 654),
#  ('effect', 654),
#  ('natural', 654),
#  ('impressive', 653),
#  ('rate', 652),
#  ('language', 652),
#  ('saying', 650),
#  ('intelligent', 650),
#  ('telling', 648),
#  ('realize', 648),
#  ('material', 648),
#  ('scott', 648),
#  ('singing', 646),
#  ('dancing', 644),
#  ('visual', 642),
#  ('adult', 642),
#  ('imagine', 642),
#  ('kept', 640),
#  ('office', 640),
#  ('uses', 638),
#  ('pure', 636),
#  ('wait', 636),
#  ('stunning', 636),
#  ('review', 634),
#  ('previous', 634),
#  ('copy', 634),
#  ('seriously', 634),
#  ('reading', 632),
#  ('create', 632),
#  ('hot', 632),
#  ('created', 632),
#  ('magic', 632),
#  ('somehow', 632),
#  ('stay', 630),
#  ('attempt', 630),
#  ('escape', 630),
#  ('crazy', 630),
#  ('air', 630),
#  ('frank', 630),
#  ('hands', 628),
#  ('filled', 626),
#  ('expected', 624),
#  ('average', 624),
#  ('surprisingly', 624),
#  ('complex', 622),
#  ('quickly', 620),
#  ('successful', 620),
#  ('studio', 620),
#  ('plus', 618),
#  ('male', 618),
#  ('co', 614),
#  ('images', 612),
#  ('casting', 612),
#  ('following', 612),
#  ('minute', 612),
#  ('exciting', 612),
#  ('members', 611),
#  ('follows', 610),
#  ('themes', 610),
#  ('german', 610),
#  ('reasons', 610),
#  ('e', 610),
#  ('touch', 608),
#  ('edge', 608),
#  ('free', 608),
#  ('cute', 608),
#  ('genius', 608),
#  ('outside', 606),
#  ('reviews', 604),
#  ('admit', 604),
#  ('ok', 604),
#  ('younger', 604),
#  ('fighting', 603),
#  ('odd', 602),
#  ('master', 602),
#  ('recent', 600),
#  ('thanks', 600),
#  ('break', 600),
#  ('comment', 600),
#  ('apart', 598),
#  ('emotions', 596),
#  ('lovely', 596),
#  ('begin', 596),
#  ('doctor', 594),
#  ('party', 594),
#  ('italian', 594),
#  ('la', 592),
#  ('missed', 592),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 1123187),
#  ('.', 335148),
#  ('the', 326867),
#  ('a', 158683),
#  ('and', 148795),
#  ('of', 138070),
#  ('to', 137976),
#  ('br', 105286),
#  ('is', 100193),
#  ('it', 96678),
#  ('i', 93789),
#  ('in', 87525),
#  ('this', 81863),
#  ('that', 75238),
#  ('s', 63110),
#  ('was', 52596),
#  ('movie', 49932),
#  ('for', 43867),
#  ('but', 43576),
#  ('with', 41775),
#  ('as', 41263),
#  ('t', 40732),
#  ('film', 38447),
#  ('you', 35104),
#  ('on', 34393),
#  ('not', 32714),
#  ('have', 30296),
#  ('are', 29250),
#  ('be', 29087),
#  ('he', 27718),
#  ('one', 26276),
#  ('they', 26027),
#  ('at', 24561),
#  ('his', 24303),
#  ('all', 24073),
#  ('so', 22932),
#  ('like', 22479),
#  ('there', 21555),
#  ('just', 21251),
#  ('by', 21106),
#  ('or', 20555),
#  ('an', 20540),
#  ('who', 19944),
#  ('from', 19464),
#  ('if', 19041),
#  ('about', 18126),
#  ('out', 17970),
#  ('what', 16847),
#  ('some', 16613),
#  ('no', 16293),
#  ('her', 15897),
#  ('even', 15379),
#  ('can', 15312),
#  ('has', 15213),
#  ('good', 14848),
#  ('bad', 14803),
#  ('would', 14074),
#  ('up', 13942),
#  ('only', 13567),
#  ('more', 13465),
#  ('when', 13457),
#  ('she', 12889),
#  ('really', 12525),
#  ('time', 12424),
#  ('had', 12287),
#  ('my', 12036),
#  ('were', 12006),
#  ('which', 11561),
#  ('very', 11529),
#  ('me', 11214),
#  ('see', 10908),
#  ('don', 10675),
#  ('we', 10658),
#  ('their', 10557),
#  ('do', 10473),
#  ('story', 10419),
#  ('than', 10371),
#  ('been', 10204),
#  ('much', 10161),
#  ('get', 10074),
#  ('because', 9932),
#  ('people', 9615),
#  ('then', 9524),
#  ('make', 9446),
#  ('could', 9379),
#  ('how', 9378),
#  ('any', 9319),
#  ('into', 9136),
#  ('made', 9084),
#  ('other', 8613),
#  ('first', 8613),
#  ('well', 8510),
#  ('too', 8353),
#  ('them', 8332),
#  ('plot', 8310),
#  ('movies', 8161),
#  ('acting', 8113),
#  ('will', 7987),
#  ('way', 7978),
#  ('most', 7839),
#  ('him', 7716),
#  ('after', 7677),
#  ('its', 7310),
#  ('think', 7289),
#  ('also', 7219),
#  ('characters', 7202),
#  ('off', 7138),
#  ('watch', 7103),
#  ('character', 7014),
#  ('did', 7012),
#  ('why', 6926),
#  ('being', 6788),
#  ('better', 6717),
#  ('know', 6670),
#  ('over', 6633),
#  ('seen', 6533),
#  ('ever', 6526),
#  ('never', 6522),
#  ('your', 6466),
#  ('where', 6441),
#  ('two', 6351),
#  ('little', 6198),
#  ('films', 6157),
#  ('here', 6055),
#  ('m', 6001),
#  ('nothing', 5982),
#  ('say', 5966),
#  ('end', 5909),
#  ('something', 5887),
#  ('should', 5843),
#  ('many', 5820),
#  ('does', 5742),
#  ('thing', 5733),
#  ('show', 5724),
#  ('ve', 5658),
#  ('scene', 5635),
#  ('scenes', 5575),
#  ('these', 5448),
#  ('go', 5434),
#  ('didn', 5293),
#  ('great', 5284),
#  ('watching', 5280),
#  ('re', 5241),
#  ('doesn', 5203),
#  ('through', 5123),
#  ('such', 5089),
#  ('man', 5034),
#  ('worst', 4961),
#  ('actually', 4899),
#  ('actors', 4876),
#  ('life', 4859),
#  ('back', 4849),
#  ('while', 4842),
#  ('director', 4811),
#  ('funny', 4672),
#  ('going', 4639),
#  ('still', 4566),
#  ('another', 4510),
#  ('look', 4496),
#  ('now', 4474),
#  ('old', 4431),
#  ('those', 4426),
#  ('real', 4341),
#  ('few', 4317),
#  ('love', 4308),
#  ('horror', 4300),
#  ('before', 4294),
#  ('want', 4283),
#  ('minutes', 4254),
#  ('pretty', 4231),
#  ('best', 4190),
#  ('though', 4183),
#  ('same', 4162),
#  ('script', 4148),
#  ('work', 4054),
#  ('every', 4050),
#  ('seems', 4046),
#  ('least', 4022),
#  ('enough', 3994),
#  ('down', 3976),
#  ('original', 3967),
#  ('guy', 3928),
#  ('got', 3904),
#  ('around', 3886),
#  ('part', 3885),
#  ('lot', 3784),
#  ('anything', 3750),
#  ('find', 3721),
#  ('new', 3710),
#  ('again', 3699),
#  ('isn', 3699),
#  ('point', 3692),
#  ('things', 3679),
#  ('fact', 3678),
#  ('give', 3646),
#  ('makes', 3628),
#  ('take', 3601),
#  ('thought', 3597),
#  ('d', 3540),
#  ('whole', 3537),
#  ('long', 3524),
#  ('years', 3518),
#  ('however', 3480),
#  ('gets', 3429),
#  ('making', 3392),
#  ('cast', 3388),
#  ('big', 3324),
#  ('might', 3317),
#  ('interesting', 3296),
#  ('money', 3276),
#  ('us', 3258),
#  ('right', 3252),
#  ('far', 3241),
#  ('quite', 3192),
#  ('without', 3191),
#  ('come', 3190),
#  ('almost', 3149),
#  ('ll', 3134),
#  ('action', 3133),
#  ('awful', 3114),
#  ('kind', 3078),
#  ('reason', 3069),
#  ('am', 3061),
#  ('looks', 3058),
#  ('must', 3044),
#  ('done', 3020),
#  ('comedy', 3009),
#  ('someone', 2980),
#  ('trying', 2973),
#  ('wasn', 2968),
#  ('poor', 2962),
#  ('boring', 2958),
#  ('instead', 2957),
#  ('saw', 2950),
#  ('away', 2938),
#  ('girl', 2926),
#  ('probably', 2888),
#  ('believe', 2868),
#  ('sure', 2867),
#  ('looking', 2860),
#  ('stupid', 2856),
#  ('anyone', 2837),
#  ('times', 2812),
#  ('maybe', 2809),
#  ('world', 2808),
#  ('rather', 2789),
#  ('terrible', 2782),
#  ('may', 2780),
#  ('last', 2780),
#  ('since', 2778),
#  ('let', 2771),
#  ('tv', 2765),
#  ('hard', 2749),
#  ('between', 2749),
#  ('waste', 2716),
#  ('woman', 2712),
#  ('feel', 2709),
#  ('effects', 2697),
#  ('half', 2682),
#  ('own', 2666),
#  ('young', 2634),
#  ('music', 2633),
#  ('idea', 2625),
#  ('sense', 2612),
#  ('bit', 2597),
#  ('having', 2561),
#  ('book', 2556),
#  ('found', 2535),
#  ('put', 2527),
#  ('series', 2526),
#  ('goes', 2513),
#  ('worse', 2499),
#  ('said', 2461),
#  ('comes', 2448),
#  ('role', 2444),
#  ('main', 2440),
#  ('else', 2399),
#  ('everything', 2394),
#  ('yet', 2392),
#  ('low', 2378),
#  ('screen', 2377),
#  ('supposed', 2373),
#  ('actor', 2370),
#  ('either', 2369),
#  ('audience', 2358),
#  ('budget', 2358),
#  ('ending', 2358),
#  ('set', 2355),
#  ('family', 2341),
#  ('left', 2339),
#  ('completely', 2336),
#  ('both', 2316),
#  ('wrong', 2310),
#  ('always', 2302),
#  ('course', 2297),
#  ('place', 2297),
#  ('seem', 2295),
#  ('watched', 2285),
#  ('day', 2264),
#  ('simply', 2261),
#  ('shot', 2252),
#  ('mean', 2234),
#  ('special', 2204),
#  ('dead', 2203),
#  ('three', 2192),
#  ('house', 2170),
#  ('oh', 2168),
#  ('night', 2166),
#  ('read', 2164),
#  ('less', 2134),
#  ('high', 2132),
#  ('year', 2128),
#  ('camera', 2122),
#  ('worth', 2114),
#  ('our', 2112),
#  ('try', 2102),
#  ('horrible', 2093),
#  ('sex', 2092),
#  ('video', 2087),
#  ('black', 2078),
#  ('although', 2075),
#  ('couldn', 2073),
#  ('once', 2067),
#  ('rest', 2045),
#  ('dvd', 2042),
#  ('line', 2036),
#  ('played', 2034),
#  ('fun', 2014),
#  ('during', 2012),
#  ('production', 2008),
#  ('everyone', 2007),
#  ('play', 1987),
#  ('mind', 1980),
#  ('version', 1979),
#  ('kids', 1978),
#  ('seeing', 1976),
#  ('american', 1960),
#  ('given', 1957),
#  ('used', 1938),
#  ('performance', 1936),
#  ('especially', 1927),
#  ('together', 1926),
#  ('tell', 1918),
#  ('women', 1916),
#  ('start', 1912),
#  ('need', 1911),
#  ('second', 1907),
#  ('takes', 1902),
#  ('each', 1900),
#  ('dialogue', 1888),
#  ('wife', 1888),
#  ('use', 1880),
#  ('problem', 1876),
#  ('star', 1869),
#  ('unfortunately', 1864),
#  ('himself', 1859),
#  ('doing', 1852),
#  ('death', 1845),
#  ('name', 1842),
#  ('lines', 1838),
#  ('killer', 1828),
#  ('getting', 1827),
#  ('help', 1812),
#  ('couple', 1806),
#  ('fan', 1805),
#  ('head', 1796),
#  ('crap', 1791),
#  ('guess', 1776),
#  ('piece', 1770),
#  ('nice', 1761),
#  ('different', 1757),
#  ('school', 1752),
#  ('later', 1750),
#  ('entire', 1738),
#  ('shows', 1720),
#  ('next', 1716),
#  ('john', 1716),
#  ('short', 1715),
#  ('seemed', 1715),
#  ('hollywood', 1700),
#  ('home', 1697),
#  ('true', 1692),
#  ('person', 1692),
#  ('absolutely', 1684),
#  ('sort', 1681),
#  ('care', 1678),
#  ('understand', 1672),
#  ('plays', 1670),
#  ('felt', 1669),
#  ('written', 1658),
#  ('title', 1656),
#  ('until', 1644),
#  ('men', 1644),
#  ('flick', 1634),
#  ('decent', 1631),
#  ('face', 1628),
#  ('friends', 1620),
#  ('stars', 1615),
#  ('job', 1614),
#  ('case', 1614),
#  ('itself', 1608),
#  ('yes', 1602),
#  ('perhaps', 1600),
#  ('went', 1594),
#  ('wanted', 1594),
#  ('called', 1592),
#  ('annoying', 1590),
#  ('ridiculous', 1580),
#  ('tries', 1580),
#  ('laugh', 1576),
#  ('along', 1574),
#  ('evil', 1574),
#  ('hour', 1570),
#  ('top', 1570),
#  ('full', 1566),
#  ('came', 1561),
#  ('writing', 1560),
#  ('keep', 1540),
#  ('totally', 1534),
#  ('playing', 1532),
#  ('god', 1530),
#  ('won', 1528),
#  ('guys', 1526),
#  ('already', 1524),
#  ('gore', 1514),
#  ('direction', 1499),
#  ('save', 1492),
#  ('lost', 1491),
#  ('example', 1489),
#  ('sound', 1485),
#  ('war', 1482),
#  ('attempt', 1470),
#  ('car', 1466),
#  ('except', 1466),
#  ('moments', 1464),
#  ('blood', 1464),
#  ('obviously', 1460),
#  ('act', 1458),
#  ('remember', 1456),
#  ('kill', 1454),
#  ('truly', 1452),
#  ('white', 1452),
#  ('father', 1452),
#  ('b', 1450),
#  ('thinking', 1440),
#  ('ok', 1432),
#  ('finally', 1432),
#  ('turn', 1422),
#  ('quality', 1402),
#  ('lack', 1398),
#  ('style', 1390),
#  ('wouldn', 1386),
#  ('cheap', 1382),
#  ('none', 1380),
#  ('kid', 1372),
#  ('please', 1372),
#  ('boy', 1370),
#  ('seriously', 1368),
#  ('lead', 1360),
#  ('dull', 1357),
#  ('starts', 1352),
#  ('children', 1352),
#  ('stuff', 1347),
#  ('hope', 1344),
#  ('looked', 1340),
#  ('recommend', 1339),
#  ('under', 1337),
#  ('run', 1335),
#  ('killed', 1334),
#  ('enjoy', 1332),
#  ('others', 1332),
#  ('etc', 1326),
#  ('myself', 1326),
#  ('beginning', 1324),
#  ('girls', 1324),
#  ('against', 1324),
#  ('obvious', 1320),
#  ('small', 1320),
#  ('hell', 1318),
#  ('slow', 1316),
#  ('hand', 1312),
#  ('wonder', 1304),
#  ('lame', 1304),
#  ('becomes', 1302),
#  ('picture', 1302),
#  ('based', 1300),
#  ('early', 1296),
#  ('behind', 1293),
#  ('poorly', 1288),
#  ('avoid', 1284),
#  ('apparently', 1280),
#  ('complete', 1280),
#  ('happens', 1279),
#  ('anyway', 1276),
#  ('classic', 1275),
#  ('several', 1272),
#  ('despite', 1270),
#  ('certainly', 1270),
#  ('episode', 1270),
#  ('often', 1262),
#  ('cut', 1261),
#  ('writer', 1260),
#  ('mother', 1256),
#  ('predictable', 1256),
#  ('gave', 1256),
#  ('become', 1255),
#  ('close', 1250),
#  ('fans', 1248),
#  ('saying', 1242),
#  ('scary', 1238),
#  ('stop', 1236),
#  ('live', 1236),
#  ('wants', 1234),
#  ('self', 1231),
#  ('mr', 1224),
#  ('jokes', 1222),
#  ('friend', 1222),
#  ('cannot', 1220),
#  ('overall', 1218),
#  ('cinema', 1208),
#  ('child', 1206),
#  ('silly', 1203),
#  ('beautiful', 1192),
#  ('human', 1190),
#  ('liked', 1189),
#  ('expect', 1188),
#  ('happened', 1185),
#  ('bunch', 1181),
#  ('entertaining', 1181),
#  ('actress', 1177),
#  ('final', 1176),
#  ('says', 1170),
#  ('performances', 1169),
#  ('turns', 1154),
#  ('humor', 1154),
#  ('themselves', 1153),
#  ('eyes', 1152),
#  ('hours', 1149),
#  ('happen', 1146),
#  ('basically', 1144),
#  ('days', 1144),
#  ('running', 1143),
#  ('involved', 1139),
#  ('disappointed', 1139),
#  ('call', 1138),
#  ('directed', 1137),
#  ('group', 1136),
#  ('fight', 1134),
#  ('daughter', 1133),
#  ('talking', 1133),
#  ('body', 1132),
#  ('badly', 1131),
#  ('sorry', 1131),
#  ('throughout', 1126),
#  ('viewer', 1126),
#  ('yourself', 1125),
#  ('extremely', 1124),
#  ('interest', 1122),
#  ('heard', 1122),
#  ('violence', 1122),
#  ('shots', 1120),
#  ('side', 1114),
#  ('word', 1112),
#  ('art', 1111),
#  ('possible', 1108),
#  ('dark', 1104),
#  ('game', 1102),
#  ('hero', 1100),
#  ('alone', 1098),
#  ('son', 1095),
#  ('type', 1094),
#  ('leave', 1094),
#  ('gives', 1093),
#  ('parts', 1092),
#  ('single', 1092),
#  ('started', 1090),
#  ('female', 1086),
#  ('rating', 1082),
#  ('mess', 1082),
#  ('voice', 1082),
#  ('aren', 1081),
#  ('town', 1080),
#  ('drama', 1077),
#  ('definitely', 1074),
#  ('unless', 1072),
#  ('review', 1068),
#  ('effort', 1066),
#  ('weak', 1066),
#  ('able', 1066),
#  ('took', 1063),
#  ('non', 1061),
#  ('five', 1060),
#  ('matter', 1058),
#  ('usually', 1058),
#  ('michael', 1057),
#  ('feeling', 1053),
#  ('huge', 1047),
#  ('sequel', 1045),
#  ('soon', 1042),
#  ('exactly', 1041),
#  ('past', 1039),
#  ('turned', 1038),
#  ('police', 1036),
#  ('tried', 1030),
#  ('middle', 1027),
#  ('talent', 1026),
#  ('genre', 1024),
#  ('zombie', 1020),
#  ('ends', 1018),
#  ('history', 1018),
#  ('straight', 1006),
#  ('opening', 1004),
#  ('serious', 1002),
#  ('coming', 1002),
#  ('moment', 1000),
#  ('lives', 999),
#  ('sad', 998),
#  ('dialog', 996),
#  ('particularly', 996),
#  ('editing', 986),
#  ('beyond', 984),
#  ('clearly', 984),
#  ('earth', 982),
#  ('taken', 981),
#  ('cool', 980),
#  ('level', 979),
#  ('dumb', 978),
#  ('okay', 976),
#  ('major', 974),
#  ('fast', 971),
#  ('premise', 970),
#  ('joke', 968),
#  ('stories', 968),
#  ('wasted', 966),
#  ('minute', 966),
#  ('across', 965),
#  ('mostly', 964),
#  ('rent', 964),
#  ('late', 962),
#  ('falls', 962),
#  ('fails', 962),
#  ('mention', 956),
#  ('theater', 951),
#  ('stay', 944),
#  ('sometimes', 944),
#  ('hit', 937),
#  ('talk', 934),
#  ('fine', 934),
#  ('die', 932),
#  ('storyline', 930),
#  ('pointless', 930),
#  ('taking', 928),
#  ('order', 924),
#  ('whatever', 922),
#  ('brother', 922),
#  ('told', 920),
#  ('wish', 916),
#  ('room', 913),
#  ('career', 912),
#  ('appears', 910),
#  ('write', 910),
#  ('known', 909),
#  ('husband', 908),
#  ('living', 902),
#  ('sit', 901),
#  ('ten', 900),
#  ('words', 898),
#  ('monster', 896),
#  ('chance', 896),
#  ('hate', 888),
#  ('novel', 888),
#  ('add', 887),
#  ('english', 886),
#  ('somehow', 882),
#  ('strange', 880),
#  ('imdb', 876),
#  ('actual', 876),
#  ('total', 874),
#  ('material', 874),
#  ('killing', 874),
#  ('ones', 874),
#  ('knew', 872),
#  ('king', 868),
#  ('number', 868),
#  ('using', 867),
#  ('lee', 864),
#  ('power', 862),
#  ('shown', 862),
#  ('works', 862),
#  ('giving', 862),
#  ('points', 860),
#  ('possibly', 860),
#  ('kept', 860),
#  ('four', 858),
#  ('local', 854),
#  ('including', 852),
#  ('usual', 852),
#  ('problems', 849),
#  ('ago', 848),
#  ('opinion', 848),
#  ('nudity', 846),
#  ('age', 844),
#  ('due', 842),
#  ('roles', 840),
#  ('writers', 838),
#  ('decided', 838),
#  ('near', 837),
#  ('flat', 836),
#  ('easily', 836),
#  ('murder', 834),
#  ('experience', 834),
#  ('reviews', 832),
#  ('imagine', 830),
#  ('feels', 826),
#  ('plain', 822),
#  ('somewhat', 822),
#  ('class', 820),
#  ('score', 820),
#  ('otherwise', 818),
#  ('song', 818),
#  ('bring', 818),
#  ('whether', 818),
#  ('whose', 816),
#  ('average', 816),
#  ('pathetic', 814),
#  ('nearly', 814),
#  ('knows', 814),
#  ('zombies', 814),
#  ('cinematography', 813),
#  ('cheesy', 812),
#  ('upon', 812),
#  ('city', 810),
#  ('space', 810),
#  ('credits', 809),
#  ('james', 808),
#  ('lots', 807),
#  ('change', 806),
#  ('entertainment', 804),
#  ('nor', 804),
#  ('wait', 802),
#  ('released', 800),
#  ('shame', 798),
#  ('needs', 798),
#  ('attention', 792),
#  ('comments', 788),
#  ('bored', 786),
#  ('free', 786),
#  ('lady', 786),
#  ('expected', 785),
#  ('needed', 785),
#  ('clear', 784),
#  ('view', 782),
#  ('development', 780),
#  ('check', 780),
#  ('doubt', 780),
#  ('excellent', 778),
#  ('figure', 778),
#  ('mystery', 778),
#  ('garbage', 776),
#  ('sequence', 773),
#  ('television', 772),
#  ('o', 770),
#  ('sets', 770),
#  ('laughable', 768),
#  ('potential', 768),
#  ('robert', 765),
#  ('light', 764),
#  ('country', 764),
#  ('documentary', 764),
#  ('reality', 764),
#  ('general', 763),
#  ('ask', 762),
#  ('comic', 761),
#  ('footage', 760),
#  ('fall', 760),
#  ('begin', 760),
#  ('stand', 758),
#  ('forced', 758),
#  ('trash', 758),
#  ('remake', 758),
#  ('thriller', 757),
#  ('songs', 756),
#  ('gay', 754),
#  ('within', 754),
#  ('hardly', 752),
#  ('george', 750),
#  ('above', 750),
#  ('gone', 750),
#  ('means', 747),
#  ('sounds', 746),
#  ('directing', 744),
#  ('move', 744),
#  ('david', 744),
#  ('buy', 744),
#  ('rock', 742),
#  ('forward', 742),
#  ('important', 742),
#  ('hot', 740),
#  ('haven', 740),
#  ('filmed', 740),
#  ('british', 740),
#  ('heart', 738),
#  ('reading', 738),
#  ('fake', 738),
#  ('incredibly', 736),
#  ('weird', 736),
#  ('hear', 736),
#  ('enjoyed', 735),
#  ('hilarious', 734),
#  ('cop', 734),
#  ('musical', 734),
#  ('message', 733),
#  ('happy', 733),
#  ('pay', 732),
#  ('laughs', 730),
#  ('box', 730),
#  ('suspense', 727),
#  ('sadly', 726),
#  ('eye', 724),
#  ('third', 723),
#  ('similar', 722),
#  ('named', 722),
#  ('modern', 720),
#  ('failed', 718),
#  ('events', 718),
#  ('forget', 717),
#  ('question', 716),
#  ('male', 714),
#  ('finds', 714),
#  ('perfect', 712),
#  ('spent', 710),
#  ('sister', 710),
#  ('feature', 708),
#  ('result', 708),
#  ('comment', 706),
#  ('girlfriend', 706),
#  ('sexual', 704),
#  ('attempts', 702),
#  ('neither', 702),
#  ('richard', 702),
#  ('screenplay', 701),
#  ('elements', 700),
#  ('spoilers', 698),
#  ('brain', 696),
#  ('filmmakers', 696),
#  ('showing', 696),
#  ('miss', 694),
#  ('dr', 694),
#  ('christmas', 694),
#  ('cover', 690),
#  ('red', 689),
#  ('sequences', 688),
#  ('typical', 686),
#  ('excuse', 686),
#  ('crazy', 685),
#  ('ideas', 685),
#  ('baby', 684),
#  ('loved', 682),
#  ('meant', 682),
#  ('worked', 680),
#  ('fire', 680),
#  ('unbelievable', 678),
#  ('follow', 678),
#  ('theme', 674),
#  ('barely', 673),
#  ('producers', 672),
#  ('twist', 672),
#  ('plus', 672),
#  ('appear', 672),
#  ('directors', 671),
#  ('team', 670),
#  ('viewers', 666),
#  ('leads', 664),
#  ('tom', 664),
#  ('slasher', 664),
#  ('wrote', 662),
#  ('villain', 662),
#  ('gun', 662),
#  ('working', 662),
#  ('island', 661),
#  ('strong', 660),
#  ('open', 660),
#  ('realize', 660),
#  ('positive', 658),
#  ('disappointing', 658),
#  ('yeah', 658),
#  ('quickly', 658),
#  ('weren', 656),
#  ('release', 656),
#  ('simple', 656),
#  ('honestly', 656),
#  ('eventually', 655),
#  ('period', 655),
#  ('tells', 654),
#  ('kills', 654),
#  ('doctor', 654),
#  ('air', 652),
#  ('nowhere', 652),
#  ('list', 652),
#  ('acted', 652),
#  ('herself', 652),
#  ('dog', 652),
#  ('walk', 650),
#  ('apart', 648),
#  ('makers', 647),
#  ('subject', 646),
#  ('learn', 644),
#  ('fi', 644),
#  ('sci', 638),
#  ('bother', 638),
#  ('admit', 638),
#  ('jack', 637),
#  ('disappointment', 636),
#  ('hands', 636),
#  ('note', 636),
#  ('certain', 634),
#  ('e', 634),
#  ('value', 634),
#  ('casting', 634),
#  ('grade', 632),
#  ('peter', 632),
#  ('suddenly', 630),
#  ('missing', 630),
#  ('form', 626),
#  ('stick', 626),
#  ('previous', 626),
#  ('break', 626),
#  ('soundtrack', 624),
#  ('parents', 622),
#  ('surprised', 622),
#  ('front', 622),
#  ('expecting', 622),
#  ('surprise', 620),
#  ('relationship', 620),
#  ('shoot', 618),
#  ('today', 618),
#  ('painful', 617),
#  ('ways', 616),
#  ('leaves', 616),
#  ('ended', 616),
#  ('creepy', 616),
#  ('concept', 616),
#  ('somewhere', 616),
#  ('vampire', 616),
#  ('future', 614),
#  ('spend', 614),
#  ('th', 614),
#  ('difficult', 612),
#  ('effect', 612),
#  ('fighting', 612),
#  ('street', 612),
#  ('c', 610),
#  ('america', 610),
#  ('accent', 608),
#  ('truth', 605),
#  ('project', 604),
#  ('joe', 603),
#  ('f', 603),
#  ('deal', 602),
#  ('indeed', 602),
#  ('biggest', 600),
#  ('rate', 600),
#  ('paul', 598),
#  ('japanese', 598),
#  ('utterly', 596),
#  ('begins', 596),
#  ('redeeming', 596),
#  ('college', 596),
#  ('york', 594),
#  ('fairly', 594),
#  ('disney', 594),
#  ('crew', 593),
#  ('create', 592),
#  ('cartoon', 592),
#  ('revenge', 592),
#  ('co', 591),
#  ('outside', 590),
#  ('computer', 590),
#  ('interested', 590),
#  ('stage', 590),
#  ('considering', 588),
#  ('speak', 588),
#  ('among', 588),
#  ('towards', 586),
#  ('channel', 586),
#  ('sick', 586),
#  ('talented', 584),
#  ('cause', 584),
#  ('particular', 584),
#  ('van', 584),
#  ('hair', 584),
#  ('bottom', 583),
#  ('reasons', 583),
#  ('mediocre', 580),
#  ('cat', 580),
#  ('telling', 580),
#  ('supporting', 578),
#  ('store', 578),
#  ('hoping', 576),
#  ('waiting', 576),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times
for word in list(total_counts):
    if total_counts[word] > 100:
        pos_neg_ratios[word] = positive_counts[word] / float(negative_counts[word]+1)

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0606881065139444
# Pos-to-neg ratio for 'amazing' = 4.0304761904761905
# Pos-to-neg ratio for 'terrible' = 0.17750628817822495

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert their values using the following formulas:
# > * For any postive words, convert the ratio using `np.log(ratio)`
# > * For any negative words, convert the ratio using `-np.log(1/(ratio + 0.01))`
#
# That second equation may look strange, but what it's doing is dividing one by a very small number, which will produce a larger positive number. Then, it takes the `log` of that, which produces numbers similar to the ones for the postive words. Finally, we negate the values by adding that minus sign up front. In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but oppositite signs.

# %%
# TODO: Convert ratios to logs
for word in list(pos_neg_ratios):
    ratio = pos_neg_ratios[word]
    pos_neg_ratios[word] = np.log(ratio) if ratio > 1 else -np.log(1/(ratio + 0.01))

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05891785460128134
# Pos-to-neg ratio for 'amazing' = 1.3938845303865663
# Pos-to-neg ratio for 'terrible' = -1.6739428971834895

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 5.3844950627890888),
#  ('paulie', 4.3652195163575005),
#  ('felix', 3.2580965380214821),
#  ('polanski', 2.9103724246028344),
#  ('matthau', 2.8638801424491884),
#  ('victoria', 2.7149230803899722),
#  ('mildred', 2.6672282065819548),
#  ('gandhi', 2.5961322848982249),
#  ('flawless', 2.5022983924998696),
#  ('superbly', 2.3025850929940459),
#  ('perfection', 2.1933858010290535),
#  ('astaire', 2.1764338076671454),
#  ('voight', 2.0693912058263346),
#  ('captures', 2.0588222544771004),
#  ('wonderfully', 2.0351412827832558),
#  ('powell', 1.9977635106655687),
#  ('brosnan', 1.9865477947871395),
#  ('lily', 1.9502298101998297),
#  ('bakshi', 1.9328380674879606),
#  ('lincoln', 1.9234372932032546),
#  ('refreshing', 1.8731998011682294),
#  ('breathtaking', 1.8700913124979619),
#  ('bourne', 1.8672670217362002),
#  ('lemmon', 1.8458266904983307),
#  ('flynn', 1.8237622003142289),
#  ('delightful', 1.8131735637318716),
#  ('homer', 1.8031881650516777),
#  ('andrews', 1.7994815153219654),
#  ('soccer', 1.791759469228055),
#  ('beautifully', 1.7705385137451697),
#  ('elvira', 1.761682013990777),
#  ('gripping', 1.7385149547092427),
#  ('underrated', 1.7362566849053676),
#  ('superb', 1.7148959843087739),
#  ('delight', 1.6916760106710724),
#  ('sadness', 1.6916760106710724),
#  ('welles', 1.6802856027649362),
#  ('timeless', 1.65455834771457),
#  ('sinatra', 1.6515754968825049),
#  ('macy', 1.6509869153469727),
#  ('touching', 1.6442846437642686),
#  ('hartley', 1.6392908755837814),
#  ('unforgettable', 1.6387901244466276),
#  ('favorites', 1.6321293236361711),
#  ('extraordinary', 1.6268296551459696),
#  ('sullivan', 1.6251862694022394),
#  ('brilliantly', 1.6070253660287164),
#  ('stewart', 1.6056089351970031),
#  ('palma', 1.5820389382459858),
#  ('friendship', 1.5780217162007213),
#  ('wonderful', 1.5662862721310362),
#  ('ritter', 1.5614984501449811),
#  ('magnificent', 1.5575660817272603),
#  ('finest', 1.5565155109797579),
#  ('jackie', 1.556193397915288),
#  ('tremendous', 1.5404450409471491),
#  ('freedom', 1.5205438866298542),
#  ('pleasantly', 1.5114575040738967),
#  ('mann', 1.5114575040738967),
#  ('fantastic', 1.5098278439047119),
#  ('sidney', 1.5091924974430444),
#  ('terrific', 1.5026699370083942),
#  ('noir', 1

#  ('highly', 1.1420208631618658),
#  ('nominated', 1.1409146683587992),
#  ('cried', 1.138732282457535),
#  ('contrast', 1.1375977353810633),
#  ('fay', 1.1373983137032662),
#  ('fabulous', 1.1325138403437911),
#  ('ned', 1.1317644959850102),
#  ('emma', 1.1284652518177909),
#  ('smooth', 1.1247234326717954),
#  ('sensitive', 1.1244917366559304),
#  ('dramas', 1.1224797700747531),
#  ('inspiring', 1.1134273744532504),
#  ('helps', 1.1078801955988911),
#  ('today', 1.1066573843529413),
#  ('stellar', 1.1051269696893034),
#  ('jimmy', 1.1010424235214014),
#  ('rival', 1.0986122886681098),
#  ('awesome', 1.0972396048561375),
#  ('depression', 1.093470889167691),
#  ('shy', 1.0933072364384164),
#  ('carrie', 1.0929465511324323),
#  ('tragic', 1.0928816139591246),
#  ('intense', 1.0928151709837839),
#  ('blend', 1.0927471692157116),
#  ('hank', 1.0923031194748449),
#  ('diana', 1.0920548881219507),
#  ('adorable', 1.0920548881219507),
#  ('unique', 1.0912708818097421),
#  ('provides', 1.0853419517472129),
#  ('achievement', 1.0826119473216687),
#  ('unexpected', 1.0800687109559406),
#  ('glorious', 1.0795640936974151),
#  ('bettie', 1.0783276174966039),
#  ('happiness', 1.0737442220900963),
#  ('ideal', 1.0666606888615073),
#  ('terrifying', 1.0661268335236214),
#  ('fears', 1.062054692934312),
#  ('davis', 1.0596101308648405),
#  ('hong', 1.053854388026616),
#  ('beauty', 1.0533556970799889),
#  ('seasons', 1.0514468202256797),
#  ('definite', 1.0481814350412177),
#  ('fascinating', 1.0463678896305901),
#  ('carries', 1.0462864696663701),
#  ('satisfying', 1.0409331770814316),
#  ('touched', 1.0407927177792835),
#  ('aunt', 1.0343179379627125),
#  ('creates', 1.0318318074640991),
#  ('walter', 1.0308396735863876),
#  ('enterprise', 1.0296194171811581),
#  ('greatest', 1.0274360102002147),
#  ('ann', 1.0263460918361891),
#  ('portrayal', 1.0226915983726381),
#  ('musicals', 1.0203600917683615),
#  ('spectacular', 1.0198314108149955),
#  ('mature', 1.0162760020074739),
#  ('deeply', 1.0153154290828954),
#  ('triumph', 1.0130901152299476),
#  ('margaret', 1.0130901152299476),
#  ('incredible', 1.0094845087721023),
#  ('lucas', 1.0033021088637848),
#  ('joey', 1.0023354582326898),
#  ('balance', 0.99792368637102624),
#  ('harry', 0.99577721444759937),
#  ('navy', 0.99493385919326827),
#  ('carrey', 0.99481549498646615),
#  ('widow', 0.99390133457907903),
#  ('guilt', 0.99373265784763409),
#  ('glover', 0.99373265784763409),
#  ('warm', 0.9929506135440711),
#  ('sweet', 0.99289212546100136),
#  ('brazil', 0.99266371065872916),
#  ('ages', 0.99187908919831114),
#  ('essence', 0.99077958386489429),
#  ('sons', 0.99004590811665028),
#  ('awe', 0.98987908853164419),
#  ('learns', 0.98690829908810851),
#  ('sport', 0.9850575891212473),
#  ('eerie', 0.98407074693589713),
#  ('visually', 0.59078516789837554),
#  ('experiences', 0.59011495466171016),
#  ('growing', 0.58935038687830177),
#  ('expressions', 0.58878716523570251),
#  ('struggles', 0.58878716523570251),
#  ('timing', 0.58870451719234795),
#  ('authentic', 0.58685252191032211),
#  ('helen', 0.58676677700137359),
#  ('clint', 0.58637920513423925),
#  ('touch', 0.58417477458571676),
#  ('quirky', 0.58333231455273871),
#  ('mexico', 0.58192154544972097),
#  ('pre', 0.58140314212032995),
#  ('timothy', 0.58122926435596001),
#  ('inner', 0.5811421221834504),
#  ('lives', 0.5810976767513224),
#  ('personalities', 0.58087987868886415),
#  ('streep', 0.58035168641460089),
#  ('sisters', 0.57955000283624003),
#  ('overcome', 0.57873682938220106),
#  ('surprises', 0.57791191698236055),
#  ('adventures', 0.57791191698236055),
#  ('civil', 0.57783633404895096),
#  ('tales', 0.57746278156048314),
#  ('realism', 0.5772280783416246),
#  ('australia', 0.576736828715534),
#  ('countries', 0.57651027683418443),
#  ('young', 0.57590953694724345),
#  ('tradition', 0.5753641449035618),
#  ('french', 0.57382517570897429),
#  ('oliver', 0.57300286871788209),
#  ('rogers', 0.57231070741667156),
#  ('wealth', 0.5721945701422827),
#  ('overwhelming', 0.5721945701422827),
#  ('odds', 0.5721945701422827),
#  ('suspenseful', 0.57085760280167108),
#  ('variety', 0.57085760280167108),
#  ('performing', 0.57008708780271811),
#  ('players', 0.56991454013599718),
#  ('war', 0.56948886118547426),
#  ('survival', 0.56884946388236812),
#  ('knowing', 0.5679840376059393),
#  ('reminiscent', 0.56745896539644858),
#  ('branagh', 0.56699589523304528),
#  ('jr', 0.56676563964833004),
#  ('howard', 0.56639547492080144),
#  ('understanding', 0.56531380905006046),
#  ('kirk', 0.56476601391173842),
#  ('grand', 0.56409006833034381),
#  ('true', 0.56340574488696504),
#  ('sent', 0.56309405231174747),
#  ('mainstream', 0.5625269981428811),
#  ('grow', 0.56224161001309025),
#  ('generation', 0.5621189181535412),
#  ('brothers', 0.56137790292882195),
#  ('dick', 0.55895111526223173),
#  ('david', 0.5582726043889551),
#  ('disc', 0.55797240219169275),
#  ('bug', 0.55797240219169275),
#  ('gangster', 0.55734563940088355),
#  ('tend', 0.55688230103976222),
#  ('jeff', 0.55634887879007433),
#  ('charm', 0.55624310345678352),
#  ('psychological', 0.55594605904646033),
#  ('sutherland', 0.55594605904646033),
#  ('twists', 0.55557719146573781),
#  ('tribute', 0.55536347819689236),
#  ('sacrifice', 0.55499684207912814),
#  ('thanks', 0.55338523818478658),
#  ('hearts', 0.55237462667886317),
#  ('europe', 0.5514966634969185),
#  ('family', 0.55116244510065526),
#  ('greek', 0.55097269177940267),
#  ('hamilton', 0.55097269177940267),
#  ('pulls', 0.55004633691927196),
#  ('describes', 0.55004633691927196),
#  ('redemption', 0.55004633691927196),
#  ('madness', 0.54875267567805175),
#  ('documentaries', 0.54831623268148932),
#  ('jealous', 0.54831623268148932),
#  ('world', 0.54800410730165927),
#  ('trial', 0.54796517071544748),
#  ('criminal', 0.44518846012601154),
#  ('wallace', 0.44496755108441072),
#  ('marry', 0.44425113314332088),
#  ('minor', 0.444112215312994),
#  ('flaws', 0.44333538216357421),
#  ('learned', 0.44326747275469958),
#  ('nazi', 0.44279106572085081),
#  ('wayne', 0.44260465505762114),
#  ('enormous', 0.44183275227903923),
#  ('michelle', 0.44183275227903923),
#  ('revolutionary', 0.44183275227903923),
#  ('de', 0.44158253333615982),
#  ('comedic', 0.44125421595974967),
#  ('slowly', 0.44094779646907262),
#  ('restaurant', 0.44031183943833246),
#  ('light', 0.44015066609605441),
#  ('cary', 0.44015066609605441),
#  ('flawed', 0.44008907267421232),
#  ('physical', 0.43945886392387695),
#  ('liked', 0.43906782895722241),
#  ('johnny', 0.43891304217570443),
#  ('married', 0.43874251496199013),
#  ('comedies', 0.43872232986464677),
#  ('international', 0.43840926382751844),
#  ('glenn', 0.43721380642274466),
#  ('vision', 0.4370394537067594),
#  ('silent', 0.43685142192883503),
#  ('sandler', 0.43660534884388763),
#  ('murder', 0.43651495949169172),
#  ('movement', 0.43567888670466093),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.0763882786651227),
#  ('uwe', -3.9194396030831955),
#  ('seagal', -3.3178813486436498),
#  ('unwatchable', -3.0231580865348979),
#  ('stinker', -2.9836231447642416),
#  ('mst', -2.7729386376804541),
#  ('incoherent', -2.7609457389729286),
#  ('unfunny', -2.5527880775662997),
#  ('waste', -2.490427936954779),
#  ('blah', -2.4451592049923065),
#  ('horrid', -2.3674337397349707),
#  ('pointless', -2.3441458135812723),
#  ('atrocious', -2.3162514610431946),
#  ('redeeming', -2.2652667164185862),
#  ('prom', -2.2558281386067116),
#  ('drivel', -2.2436572605401586),
#  ('lousy', -2.2095445464835692),
#  ('worst', -2.1930856334332267),
#  ('laughable', -2.1712831017143799),
#  ('awful', -2.1382139473239339),
#  ('poorly', -2.1319032943666651),
#  ('wasting', -2.1144379793294084),
#  ('remotely', -2.1083600797260411),
#  ('existent', -1.9992594708954894),
#  ('boredom', -1.9204146460163511),
#  ('miserably', -1.917415884505784),
#  ('sucks', -1.9147834875998957),
#  ('uninspired', -1.9131499212248517),
#  ('lame', -1.9110090970465483),
#  ('insult', -1.9060486156301826)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = list(total_counts)

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'bromwell': 0,
#  'high': 1,
#  'is': 2,
#  'a': 3,
#  'cartoon': 4,
#  'comedy': 5,
#  '.': 6,
#  'it': 7,
#  'ran': 8,
#  'at': 9,
#  'the': 10,
#  'same': 11,
#  'time': 12,
#  'as': 13,
#  'some': 14,
#  'other': 15,
#  'programs': 16,
#  'about': 17,
#  'school': 18,
#  'life': 19,
#  '': 20,
#  'such': 21,
#  'teachers': 22,
#  'my': 23,
#  'years': 24,
#  'in': 25,
#  'teaching': 26,
#  'profession': 27,
#  'lead': 28,
#  'me': 29,
#  'to': 30,
#  'believe': 31,
#  'that': 32,
#  's': 33,
#  'satire': 34,
#  'much': 35,
#  'closer': 36,
#  'reality': 37,
#  'than': 38,
#  'scramble': 39,
#  'survive': 40,
#  'financially': 41,
#  'insightful': 42,
#  'students': 43,
#  'who': 44,
#  'can': 45,
#  'see': 46,
#  'right': 47,
#  'through': 48,
#  'their': 49,
#  'pathetic': 50,
#  'pomp': 51,
#  'pettiness': 52,
#  'of': 53,
#  'whole': 54,
#  'situation': 55,
#  'all': 56,
#  'remind': 57,
#  'schools': 58,
#  'i': 59,
#  'knew': 60,
#  'and': 61,
#  'when': 62,
#  'saw': 63,
#  'episode': 64,
#  'which': 65,
#  'student': 66,
#  'repeatedly': 67,
#  'tried': 68,
#  'burn': 69,
#  'down': 70,
#  'immediately': 71,
#  'recalled': 72,
#  'classic': 73,
#  'line': 74,
#  'inspector': 75,
#  'm': 76,
#  'here': 77,
#  'sack': 78,
#  'one': 79,
#  'your': 80,
#  'welcome': 81,
#  'expect': 82,
#  'many': 83,
#  'adults': 84,
#  'age': 85,
#  'think': 86,
#  'far': 87,
#  'fetched': 88,
#  'what': 89,
#  'pity': 90,
#  'isn': 91,
#  't': 92,
#  'story': 93,
#  'man': 94,
#  'has': 95,
#  'unnatural': 96,
#  'feelings': 97,
#  'for': 98,
#  'pig': 99,
#  'starts': 100,
#  'out': 101,
#  'with': 102,
#  'opening': 103,
#  'scene': 104,
#  'terrific': 105,
#  'example': 106,
#  'absurd': 107,
#  'formal': 108,
#  'orchestra': 109,
#  'audience': 110,
#  'turned': 111,
#  'into': 112,
#  'an': 113,
#  'insane': 114,
#  'violent': 115,
#  'mob': 116,
#  'by': 117,
#  'crazy': 118,
#  'chantings': 119,
#  'singers': 120,
#  'unfortunately': 121,
#  'stays': 122,
#  'no': 123,
#  'general': 124,
#  'narrative': 125,
#  'eventually': 126,
#  'making': 127,
#  'just': 128,
#  'too': 129,
#  'off': 130,
#  'putting': 131,
#  'even': 132,
#  'those': 133,
#  'from': 134,
#  'era': 135,
#  'should': 136,
#  'be': 137,
#  'cryptic': 138,
#  'dialogue': 139,
#  'would': 140,
#  'make': 141,
#  'shakespeare': 142,
#  'seem': 143,
#  'easy': 144,
#  'third': 145,
#  'grader': 146,
#  'on': 147,
#  'technical': 148,
#  'level': 149,
#  'better': 150,
#  'you': 151,
#  'might': 152,
#  'good': 153,
#  'cinematography': 154,
#  'future': 155,
#  'great': 156,
#  'vilmos': 157,
#  'zsigmond': 158,
#  'stars': 159,
#  'sally': 160,
#  'kirkland': 161,
#  'frederic': 162,
#  'forrest': 163,
#  'seen': 164,
#  'briefly': 165,
#  'homelessness': 166,
#  'or': 167,
#  'houselessness': 168,
#  'george': 169,
#  'carlin': 170,
#  'stated': 171,
#  'been': 172,
#  'issue': 173,
#  'but': 174,
#  'never': 175,
#  'plan': 176,
#  'help': 177,
#  'street': 178,
#  'were': 179,
#  'once': 180,
#  'considered': 181,
#  'human': 182,
#  'did': 183,
#  'everything': 184,
#  'going': 185,
#  'work': 186,
#  'vote': 187,
#  'matter': 188,
#  'most': 189,
#  'people': 190,
#  'homeless': 191,
#  'lost': 192,
#  'cause': 193,
#  'while': 194,
#  'worrying': 195,
#  'things': 196,
#  'racism': 197,
#  'war': 198,
#  'iraq': 199,
#  'pressuring': 200,
#  'kids': 201,
#  'succeed': 202,
#  'technology': 203,
#  'elections': 204,
#  'inflation': 205,
#  'if': 206,
#  'they': 207,
#  'll': 208,
#  'next': 209,
#  'end': 210,
#  'up': 211,
#  'streets': 212,
#  'br': 213,
#  'given': 214,
#  'bet': 215,
#  'live': 216,
#  'month': 217,
#  'without': 218,
#  'luxuries': 219,
#  'had': 220,
#  'home': 221,
#  'entertainment': 222,
#  'sets': 223,
#  'bathroom': 224,
#  'pictures': 225,
#  'wall': 226,
#  'computer': 227,
#  'treasure': 228,
#  'like': 229,
#  'goddard': 230,
#  'bolt': 231,
#  'lesson': 232,
#  'mel': 233,
#  'brooks': 234,
#  'directs': 235,
#  'plays': 236,
#  'rich': 237,
#  'world': 238,
#  'until': 239,
#  'deciding': 240,
#  'sissy': 241,
#  'rival': 242,
#  'jeffery': 243,
#  'tambor': 244,
#  'he': 245,
#  'thirty': 246,
#  'days': 247,
#  'succeeds': 248,
#  'do': 249,
#  'wants': 250,
#  'project': 251,
#  'more': 252,
#  'buildings': 253,
#  'where': 254,
#  'thrown': 255,
#  'bracelet': 256,
#  'his': 257,
#  'leg': 258,
#  'monitor': 259,
#  'every': 260,
#  'move': 261,
#  'step': 262,
#  'sidewalk': 263,
#  'nickname': 264,
#  'pepto': 265,
#  'vagrant': 266,
#  'after': 267,
#  'written': 268,
#  'forehead': 269,
#  'meets': 270,
#  'characters': 271,
#  'including': 272,
#  'woman': 273,
#  'name': 274,
#  'molly': 275,
#  'lesley': 276,
#  'ann': 277,
#  'warren': 278,
#  'ex': 279,
#  'dancer': 280,
#  'got': 281,
#  'divorce': 282,
#  'before': 283,
#  'losing': 284,
#  'her': 285,
#  'pals': 286,
#  'sailor': 287,
#  'howard': 288,
#  'morris': 289,
#  'fumes': 290,
#  'teddy': 291,
#  'wilson': 292,
#  'are': 293,
#  'already': 294,
#  'used': 295,
#  're': 296,
#  'survivors': 297,
#  'not': 298,
#  'reaching': 299,
#  'mutual': 300,
#  'agreements': 301,
#  'being': 302,
#  'fight': 303,
#  'flight': 304,
#  'kill': 305,
#  'killed': 306,
#  'love': 307,
#  'connection': 308,
#  'between': 309,
#  'wasn': 310,
#  'necessary': 311,
#  'plot': 312,
#  'found': 313,
#  'stinks': 314,
#  'observant': 315,
#  'films': 316,
#  'prior': 317,
#  'shows': 318,
#  'tender': 319,
#  'side': 320,
#  'compared': 321,
#  'slapstick': 322,
#  'blazing': 323,
#  'saddles': 324,
#  'young': 325,
#  'frankenstein': 326,
#  'spaceballs': 327,
#  'show': 328,
#  'having': 329,
#  'something': 330,
#  'valuable': 331,
#  'day': 332,
#  'hand': 333,
#  'stupid': 334,
#  'don': 335,
#  'know': 336,
#  'money': 337,
#  'maybe': 338,
#  'give': 339,
#  'instead': 340,
#  'using': 341,
#  'monopoly': 342,
#  'this': 343,
#  'film': 344,
#  'will': 345,
#  'inspire': 346,
#  'others': 347,
#  'airport': 348,
#  'brand': 349,
#  'new': 350,
#  'luxury': 351,
#  'plane': 352,
#  'loaded': 353,
#  'paintings': 354,
#  'belonging': 355,
#  'businessman': 356,
#  'philip': 357,
#  'stevens': 358,
#  'james': 359,
#  'stewart': 360,
#  'flying': 361,
#  'them': 362,
#  'bunch': 363,
#  'vip': 364,
#  'estate': 365,
#  'preparation': 366,
#  'opened': 367,
#  'public': 368,
#  'museum': 369,
#  'also': 370,
#  'board': 371,
#  'daughter': 372,
#  'julie': 373,
#  'kathleen': 374,
#  'quinlan': 375,
#  'son': 376,
#  'jetliner': 377,
#  'takes': 378,
#  'planned': 379,
#  'mid': 380,
#  'air': 381,
#  'hi': 382,
#  'jacked': 383,
#  'co': 384,
#  'pilot': 385,
#  'chambers': 386,
#  'robert': 387,
#  'foxworth': 388,
#  'two': 389,
#  'accomplice': 390,
#  'banker': 391,
#  'monte': 392,
#  'markham': 393,
#  'michael': 394,
#  'pataki': 395,
#  'knock': 396,
#  'passengers': 397,
#  'crew': 398,
#  'sleeping': 399,
#  'gas': 400,
#  'steal': 401,
#  'cargo': 402,
#  'land': 403,
#  'disused': 404,
#  'strip': 405,
#  'isolated': 406,
#  'island': 407,
#  'descent': 408,
#  'almost': 409,
#  'hits': 410,
#  'oil': 411,
#  'rig': 412,
#  'ocean': 413,
#  'loses': 414,
#  'control': 415,
#  'sending': 416,
#  'crashing': 417,
#  'sea': 418,
#  'sinks': 419,
#  'bottom': 420,
#  'bang': 421,
#  'middle': 422,
#  'bermuda': 423,
#  'triangle': 424,
#  'short': 425,
#  'supply': 426,
#  'water': 427,
#  'leaking': 428,
#  'flown': 429,
#  'over': 430,
#  'miles': 431,
#  'course': 432,
#  'problems': 433,
#  'mount': 434,
#  'survivor': 435,
#  'await': 436,
#  'fast': 437,
#  'running': 438,
#  'known': 439,
#  'under': 440,
#  'slightly': 441,
#  'different': 442,
#  'tile': 443,
#  'second': 444,
#  'sequel': 445,
#  'smash': 446,
#  'hit': 447,
#  'disaster': 448,
#  'thriller': 449,
#  'was': 450,
#  'directed': 451,
#  'jerry': 452,
#  'jameson': 453,
#  'again': 454,
#  'predecessors': 455,
#  'say': 456,
#  'any': 457,
#  'sort': 458,
#  'forgotten': 459,
#  'entertaining': 460,
#  'although': 461,
#  'necessarily': 462,
#  'reasons': 463,
#  'three': 464,
#  'have': 465,
#  'so': 466,
#  'actually': 467,
#  'liked': 468,
#  'best': 469,
#  'favourite': 470,
#  'nice': 471,
#  'jacking': 472,
#  'then': 473,
#  'didn': 474,
#  'sinking': 475,
#  'makers': 476,
#  'trying': 477,
#  'cross': 478,
#  'original': 479,
#  'another': 480,
#  'popular': 481,
#  'flick': 482,
#  'period': 483,
#  'poseidon': 484,
#  'adventure': 485,
#  'submerged': 486,
#  'stark': 487,
#  'dilemma': 488,
#  'facing': 489,
#  'trapped': 490,
#  'inside': 491,
#  'either': 492,
#  'suffocate': 493,
#  'runs': 494,
#  'drown': 495,
#  'floods': 496,
#  'doors': 497,
#  'decent': 498,
#  'idea': 499,
#  'could': 500,
#  'made': 501,
#  'little': 502,
#  'bad': 503,
#  'unsympathetic': 504,
#  'character': 505,
#  'dull': 506,
#  'lethargic': 507,
#  'set': 508,
#  'pieces': 509,
#  'real': 510,
#  'lack': 511,
#  'danger': 512,
#  'suspense': 513,
#  'tension': 514,
#  'means': 515,
#  'missed': 516,
#  'opportunity': 517,
#  'rather': 518,
#  'sluggish': 519,
#  'keeps': 520,
#  'entertained': 521,
#  'odd': 522,
#  'minutes': 523,
#  'happens': 524,
#  'there': 525,
#  'urgency': 526,
#  'thought': 527,
#  'navy': 528,
#  'become': 529,
#  'involved': 530,
#  'pick': 531,
#  'few': 532,
#  'shots': 533,
#  'huge': 534,
#  'ships': 535,
#  'helicopters': 536,
#  'lacking': 537,
#  'kennedy': 538,
#  'jinxed': 539,
#  'airline': 540,
#  'worker': 541,
#  'joe': 542,
#  'patroni': 543,
#  'back': 544,
#  'only': 545,
#  'gets': 546,
#  'couple': 547,
#  'scenes': 548,
#  'barely': 549,
#  'says': 550,
#  'anything': 551,
#  'preferring': 552,
#  'look': 553,
#  'worried': 554,
#  'background': 555,
#  'video': 556,
#  'theatrical': 557,
#  'version': 558,
#  'run': 559,
#  'us': 560,
#  'tv': 561,
#  'versions': 562,
#  'add': 563,
#  'extra': 564,
#  'hour': 565,
#  'footage': 566,
#  'credits': 567,
#  'sequence': 568,
#  'flashbacks': 569,
#  'flesh': 570,
#  'longer': 571,
#  'rescue': 572,
#  'discovery': 573,
#  'dead': 574,
#  'bodies': 575,
#  'navigator': 576,
#  'am': 577,
#  'sure': 578,
#  'sit': 579,
#  'near': 580,
#  'cut': 581,
#  'expected': 582,
#  'dated': 583,
#  'badly': 584,
#  'horrible': 585,
#  'fashions': 586,
#  'interior': 587,
#  'design': 588,
#  'choices': 589,
#  'toy': 590,
#  'model': 591,
#  'effects': 592,
#  'aren': 593,
#  'along': 594,
#  'sequels': 595,
#  'pride': 596,
#  'place': 597,
#  'razzie': 598,
#  'award': 599,
#  'hall': 600,
#  'shame': 601,
#  'lots': 602,
#  'worse': 603,
#  'reckon': 604,
#  'harsh': 605,
#  'action': 606,
#  'pace': 607,
#  'slow': 608,
#  'excitement': 609,
#  'generated': 610,
#  'pretty': 611,
#  'properly': 612,
#  'production': 613,
#  'values': 614,
#  'alright': 615,
#  'nothing': 616,
#  'spectacular': 617,
#  'acting': 618,
#  'oscar': 619,
#  'winner': 620,
#  'jack': 621,
#  'lemmon': 622,
#  'said': 623,
#  'since': 624,
#  'mistake': 625,
#  'star': 626,
#  'looks': 627,
#  'old': 628,
#  'frail': 629,
#  'lee': 630,
#  'grant': 631,
#  'drunk': 632,
#  'sir': 633,
#  'christopher': 634,
#  'plenty': 635,
#  'familiar': 636,
#  'faces': 637,
#  'orientated': 638,
#  'ideas': 639,
#  'behind': 640,
#  'bit': 641,
#  'silly': 642,
#  'bland': 643,
#  'direction': 644,
#  'doesn': 645,
#  'though': 646,
#  'sunken': 647,
#  'shouldn': 648,
#  'boring': 649,
#  'followed': 650,
#  'concorde': 651,
#  'brilliant': 652,
#  'dramatic': 653,
#  'hobo': 654,
#  'lady': 655,
#  'ever': 656,
#  'clothes': 657,
#  'warehouse': 658,
#  'none': 659,
#  'corn': 660,
#  'face': 661,
#  'take': 662,
#  'lawyers': 663,
#  'superb': 664,
#  'accused': 665,
#  'turncoat': 666,
#  'selling': 667,
#  'boss': 668,
#  'dishonest': 669,
#  'lawyer': 670,
#  'shrugs': 671,
#  'indifferently': 672,
#  'funny': 673,
#  'words': 674,
#  'jeffrey': 675,
#  'favorite': 676,
#  'later': 677,
#  'larry': 678,
#  'sanders': 679,
#  'fantastic': 680,
#  'mad': 681,
#  'millionaire': 682,
#  'crush': 683,
#  'ghetto': 684,
#  'malevolent': 685,
#  'usual': 686,
#  'hospital': 687,
#  'invade': 688,
#  'demolition': 689,
#  'site': 690,
#  'classics': 691,
#  'legs': 692,
#  'big': 693,
#  'diggers': 694,
#  'fighting': 695,
#  'bleeds': 696,
#  'movie': 697,
#  'each': 698,
#  'quite': 699,
#  'often': 700,
#  'lacked': 701,
#  'couldn': 702,
#  'put': 703,
#  'finger': 704,
#  'first': 705,
#  'charisma': 706,
#  'part': 707,
#  'leading': 708,
#  'actress': 709,
#  'inevitably': 710,
#  'translated': 711,
#  'chemistry': 712,
#  'she': 713,
#  'shared': 714,
#  'screen': 715,
#  'romantic': 716,
#  'came': 717,
#  'across': 718,
#  'merely': 719,
#  'actors': 720,
#  'play': 721,
#  'very': 722,
#  'well': 723,
#  'director': 724,
#  'miscalculated': 725,
#  'needed': 726,
#  'screenplay': 727,
#  'exactly': 728,
#  'chef': 729,
#  'seemed': 730,
#  'enamored': 731,
#  'culinary': 732,
#  'skills': 733,
#  'restaurant': 734,
#  'ultimately': 735,
#  'himself': 736,
#  'youthful': 737,
#  'exploits': 738,
#  'anybody': 739,
#  'else': 740,
#  'convinced': 741,
#  'princess': 742,
#  'disappointed': 743,
#  'forget': 744,
#  'nominated': 745,
#  'judge': 746,
#  'yourself': 747,
#  'easily': 748,
#  'underrated': 749,
#  'inn': 750,
#  'cannon': 751,
#  'its': 752,
#  'flawed': 753,
#  'does': 754,
#  'realistic': 755,
#  'view': 756,
#  'unlike': 757,
#  'how': 758,
#  'citizen': 759,
#  'kane': 760,
#  'gave': 761,
#  'lounge': 762,
#  'titanic': 763,
#  'italians': 764,
#  'idiots': 765,
#  'jokes': 766,
#  'fall': 767,
#  'flat': 768,
#  'still': 769,
#  'lovable': 770,
#  'way': 771,
#  'comedies': 772,
#  'pull': 773,
#  'traditionally': 774,
#  'reviled': 775,
#  'members': 776,
#  'society': 777,
#  'truly': 778,
#  'impressive': 779,
#  'fisher': 780,
#  'king': 781,
#  'crap': 782,
#  'complaint': 783,
#  'cast': 784,
#  'someone': 785,
#  'writer': 786,
#  'sorry': 787,
#  'everyone': 788,
#  'supposed': 789,
#  'art': 790,
#  'wow': 791,
#  'handed': 792,
#  'guns': 793,
#  'screening': 794,
#  'blow': 795,
#  'brains': 796,
#  'watch': 797,
#  'photographic': 798,
#  'excellent': 799,
#  'painful': 800,
#  'absence': 801,
#  'sound': 802,
#  'track': 803,
#  'brutal': 804,
#  'loooonnnnng': 805,
#  'long': 806,
#  'sitting': 807,
#  'talking': 808,
#  'especially': 809,
#  'complaining': 810,
#  'really': 811,
#  'hard': 812,
#  'getting': 813,
#  'performances': 814,
#  'dark': 815,
#  'sombre': 816,
#  'uninspired': 817,
#  'stuff': 818,
#  'thing': 819,
#  'maureen': 820,
#  'stapleton': 821,
#  'red': 822,
#  'dress': 823,
#  'dancing': 824,
#  'otherwise': 825,
#  'ripoff': 826,
#  'bergman': 827,
#  'fan': 828,
#  'f': 829,
#  'anyone': 830,
#  'enjoyed': 831,
#  'hours': 832,
#  'lying': 833,
#  'typical': 834,
#  'less': 835,
#  'movies': 836,
#  'followable': 837,
#  'leslie': 838,
#  'rated': 839,
#  'moments': 840,
#  'fleshed': 841,
#  'probably': 842,
#  'room': 843,
#  'worth': 844,
#  'price': 845,
#  'rent': 846,
#  'overall': 847,
#  'job': 848,
#  'characteristic': 849,
#  'speaking': 850,
#  'directly': 851,
#  'actor': 852,
#  'fume': 853,
#  'both': 854,
#  'played': 855,
#  'parts': 856,
#  'parents': 857,
#  'took': 858,
#  'theater': 859,
#  'interiors': 860,
#  'watched': 861,
#  'we': 862,
#  'walked': 863,
#  'recently': 864,
#  'lived': 865,
#  'rest': 866,
#  'pretentious': 867,
#  'ponderous': 868,
#  'painfully': 869,
#  'piece': 870,
#  'wine': 871,
#  'cheese': 872,
#  'tripe': 873,
#  'woody': 874,
#  'allen': 875,
#  'directors': 876,
#  'worst': 877,
#  'career': 878,
#  'unmistakable': 879,
#  'style': 880,
#  'ingmar': 881,
#  'berman': 882,
#  'gives': 883,
#  'angular': 884,
#  'muted': 885,
#  'insight': 886,
#  'lives': 887,
#  'family': 888,
#  'wrought': 889,
#  'psychological': 890,
#  'damage': 891,
#  'caused': 892,
#  'estrangement': 893,
#  'non': 894,
#  'halitosis': 895,
#  'whatever': 896,
#  'intentionally': 897,
#  'comic': 898,
#  'relief': 899,
#  'music': 900,
#  'drenched': 901,
#  'shadowy': 902,
#  'pathos': 903,
#  'defined': 904,
#  'expressionist': 905,
#  'nature': 906,
#  'improvisational': 907,
#  'method': 908,
#  'illicit': 909,
#  'pronounced': 910,
#  'depth': 911,
#  'meaning': 912,
#  'truth': 913,
#  'beyond': 914,
#  'simply': 915,
#  'sympathy': 916,
#  'felt': 917,
#  'contempt': 918,
#  'parade': 919,
#  'shuffling': 920,
#  'whining': 921,
#  'nicotine': 922,
#  'stained': 923,
#  'martyrs': 924,
#  'perpetual': 925,
#  'quest': 926,
#  'identity': 927,
#  'amid': 928,
#  'backdrop': 929,
#  'cosmopolitan': 930,
#  'affluence': 931,
#  'baked': 932,
#  'brie': 933,
#  'intelligentsia': 934,
#  'looms': 935,
#  'fart': 936,
#  'speaks': 937,
#  'affected': 938,
#  'platitudes': 939,
#  'elevated': 940,
#  'language': 941,
#  'cigarettes': 942,
#  'struggling': 943,
#  'desperate': 944,
#  'find': 945,
#  'understanding': 946,
#  'goes': 947,
#  'point': 948,
#  'want': 949,
#  'slap': 950,
#  'resolution': 951,
#  'interminable': 952,
#  'introspective': 953,
#  'babble': 954,
#  'drama': 955,
#  'taken': 956,
#  'extreme': 957,
#  'ability': 958,
#  'connect': 959,
#  'chose': 960,
#  'immersed': 961,
#  'themselves': 962,
#  'feel': 963,
#  'left': 964,
#  'reason': 965,
#  'self': 966,
#  'indulgent': 967,
#  'spiritually': 968,
#  'draining': 969,
#  'insistence': 970,
#  'promoting': 971,
#  'message': 972,
#  'prozac': 973,
#  'prose': 974,
#  'distorted': 975,
#  'techniques': 976,
#  'jettisons': 977,
#  'past': 978,
#  'relevance': 979,
#  'highly': 980,
#  'recommend': 981,
#  'feeling': 982,
#  'happy': 983,
#  'need': 984,
#  'death': 985,
#  'let': 986,
#  'pretend': 987,
#  'happened': 988,
#  'comedic': 989,
#  'robin': 990,
#  'williams': 991,
#  'nor': 992,
#  'quirky': 993,
#  'recent': 994,
#  'fame': 995,
#  'hybrid': 996,
#  'dramatization': 997,
#  'mixed': 998,
#  'per': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    print ("layer_0 shape: ", layer_0.shape);
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    counts = Counter()
    for word in review.split(' '):
        counts[word] += 1
    
    for word in list(counts):
        print(word, "index: ", word2index[word], "count: ", counts[word])
        layer_0[0][word2index[word]] = counts[word]

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# layer_0 shape:  (1, 74074)
# bromwell index:  0 count:  4
# high index:  1 count:  5
# is index:  2 count:  4
# a index:  3 count:  4
# cartoon index:  4 count:  1
# comedy index:  5 count:  1
# . index:  6 count:  27
# it index:  7 count:  2
# ran index:  8 count:  1
# at index:  9 count:  2
# the index:  10 count:  9
# same index:  11 count:  1
# time index:  12 count:  1
# as index:  13 count:  2
# some index:  14 count:  1
# other index:  15 count:  1
# programs index:  16 count:  1
# about index:  17 count:  1
# school index:  18 count:  2
# life index:  19 count:  1
#  index:  20 count:  18
# such index:  21 count:  1
# teachers index:  22 count:  4
# my index:  23 count:  2
# years index:  24 count:  1
# in index:  25 count:  2
# teaching index:  26 count:  1
# profession index:  27 count:  1
# lead index:  28 count:  1
# me index:  29 count:  2
# to index:  30 count:  6
# believe index:  31 count:  1
# that index:  32 count:  4
# s index:  33 count:  1
# satire index:  34 count:  1
# much index:  35 count:  1
# closer index:  36 count:  1
# reality index:  37 count:  1
# than index:  38 count:  1
# scramble index:  39 count:  1
# survive index:  40 count:  1
# financially index:  41 count:  1
# insightful index:  42 count:  1
# students index:  43 count:  2
# who index:  44 count:  1
# can index:  45 count:  1
# see index:  46 count:  1
# right index:  47 count:  1
# through index:  48 count:  1
# their index:  49 count:  2
# pathetic index:  50 count:  1
# pomp index:  51 count:  1
# pettiness index:  52 count:  1
# of index:  53 count:  4
# whole index:  54 count:  1
# situation index:  55 count:  1
# all index:  56 count:  1
# remind index:  57 count:  1
# schools index:  58 count:  1
# i index:  59 count:  5
# knew index:  60 count:  1
# and index:  61 count:  1
# when index:  62 count:  1
# saw index:  63 count:  1
# episode index:  64 count:  1
# which index:  65 count:  1
# student index:  66 count:  2
# repeatedly index:  67 count:  1
# tried index:  68 count:  1
# burn index:  69 count:  1
# down index:  70 count:  1
# immediately index:  71 count:  1
# recalled index:  72 count:  1
# classic index:  73 count:  1
# line index:  74 count:  1
# inspector index:  75 count:  1
# m index:  76 count:  1
# here index:  77 count:  1
# sack index:  78 count:  1
# one index:  79 count:  1
# your index:  80 count:  1
# welcome index:  81 count:  1
# expect index:  82 count:  1
# many index:  83 count:  1
# adults index:  84 count:  1
# age index:  85 count:  1
# think index:  86 count:  1
# far index:  87 count:  1
# fetched index:  88 count:  1
# what index:  89 count:  1
# pity index:  90 count:  1
# isn index:  91 count:  1
# t index:  92 count:  1
# array([[ 4.,  5.,  4., ...,  0.,  0.,  0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    return 1 if label == 'POSITIVE' else 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab), hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        for k,review in enumerate(reviews):
            for word in review.lower().split(' '):
                review_vocab.add(word)
        
        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        for label in labels:
            label_vocab |= set([label])
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        for k,word in enumerate(self.review_vocab):
            self.word2index[word] = k
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
        for k,label in enumerate(self.label_vocab):
            self.label2index[label] = k
            
        print("Finished preprocessing data: words#", self.review_vocab_size, "labels#",  self.label_vocab_size)
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.hidden_nodes**-0.5, (self.hidden_nodes, self.output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1, input_nodes))
    
    # Update the input layer with the words in this specific review
    # 
    def update_input_layer(self,review):
        # clear out previous state by resetting the layer to be all 0s
        self.layer_0 *= 0
#         print("shape of layer_0", self.layer_0.shape)

        for word in review.split(" "):
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        return 1 if label == 'POSITIVE' else 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return 1 * (1 - output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            target = self.get_target_for_label(label)
            self.update_input_layer(review)
            
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            
            # Forward pass
            # Hidden layer
            hidden_inputs = np.dot(self.layer_0, self.weights_0_1) # signals into hidden layer
            hidden_outputs = hidden_inputs # signals from hidden layer, no activation
            
            # Output layer
            final_inputs = np.dot(hidden_outputs, self.weights_1_2) # signals into final output layer
            final_outputs = self.sigmoid(final_inputs) # signals from final output layer w activation
            
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            
            # Backward pass
            error = target - final_outputs # Output layer error is the difference between desired target and actual output.
            output_error_term = error * self.sigmoid_output_2_derivative(final_outputs)
            
            hidden_error = np.dot(output_error_term, self.weights_1_2.T) # The hidden layer's contribution to the error
#             print("Error: ", error, self.weights_hidden_to_output, hidden_error)
            
            hidden_error_term = hidden_error # f'(x) = 1
        
            delta_weights_0_1 = hidden_error_term * self.layer_0.T
            delta_weights_1_2 = output_error_term * hidden_outputs.T
            
            # Update weights
            self.weights_0_1 += self.learning_rate * delta_weights_0_1 # update input-to-hidden weights with gradient descent step
            self.weights_1_2 += self.learning_rate * delta_weights_1_2 # update hidden-to-output weights with gradient descent step
            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            
            if (abs(error) < 0.5):
                correct_so_far += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        lc_review = review.lower();
        target = self.get_target_for_label
        self.update_input_layer(lc_review)
        
        hidden_inputs = np.dot(self.layer_0, self.weights_0_1) # signals into hidden layer
        hidden_outputs = hidden_inputs # signals from hidden layer
        
        final_inputs = np.dot(hidden_outputs, self.weights_1_2) # signals into final output layer
        final_outputs = self.sigmoid(final_inputs) # signals from final output layer 
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        return 'POSITIVE' if final_outputs >= 0.5 else 'NEGATIVE'

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews, labels, learning_rate=0.1)
# Out:
# Finished preprocessing data: words# 74074 labels# 2

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.9% Speed(reviews/sec):1121. #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:10.4% Speed(reviews/sec):1161. #Correct:0 #Trained:2501 Training Accuracy:0.0%
# Progress:20.8% Speed(reviews/sec):1136. #Correct:0 #Trained:5001 Training Accuracy:0.0%
# Progress:31.2% Speed(reviews/sec):1133. #Correct:0 #Trained:7501 Training Accuracy:0.0%
# Progress:41.6% Speed(reviews/sec):1136. #Correct:0 #Trained:10001 Training Accuracy:0.0%
# Progress:52.0% Speed(reviews/sec):1115. #Correct:0 #Trained:12501 Training Accuracy:0.0%
# Progress:62.5% Speed(reviews/sec):1102. #Correct:0 #Trained:15001 Training Accuracy:0.0%
# Progress:72.9% Speed(reviews/sec):1092. #Correct:0 #Trained:17501 Training Accuracy:0.0%
# Progress:83.3% Speed(reviews/sec):1085. #Correct:0 #Trained:20001 Training Accuracy:0.0%
# Progress:93.7% Speed(reviews/sec):1078. #Correct:0 #Trained:22501 Training Accuracy:0.0%
# Progress:99.9% Speed(reviews/sec):1074. #Correct:0 #Trained:24000 Training Accuracy:0.0%

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Finished preprocessing data: words# 72810 labels# 2
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):1177. #Correct:1221 #Trained:2501 Training Accuracy:48.8%
# Progress:20.8% Speed(reviews/sec):1151. #Correct:2441 #Trained:5001 Training Accuracy:48.8%
# Progress:31.2% Speed(reviews/sec):1112. #Correct:3672 #Trained:7501 Training Accuracy:48.9%
# Progress:41.6% Speed(reviews/sec):1089. #Correct:4895 #Trained:10001 Training Accuracy:48.9%
# Progress:52.0% Speed(reviews/sec):1066. #Correct:6128 #Trained:12501 Training Accuracy:49.0%
# Progress:62.5% Speed(reviews/sec):1044. #Correct:7370 #Trained:15001 Training Accuracy:49.1%
# Progress:72.9% Speed(reviews/sec):1034. #Correct:8599 #Trained:17501 Training Accuracy:49.1%
# Progress:83.3% Speed(reviews/sec):1025. #Correct:9841 #Trained:20001 Training Accuracy:49.2%
# Progress:93.7% Speed(reviews/sec):1013. #Correct:11056 #Trained:22501 Training Accuracy:49.1%
# Progress:99.9% Speed(reviews/sec):1008. #Correct:11794 #Trained:24000 Training Accuracy:49.1%

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Finished preprocessing data: words# 72810 labels# 2
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:10.4% Speed(reviews/sec):260.6 #Correct:1257 #Trained:2501 Training Accuracy:50.2%
# Progress:20.8% Speed(reviews/sec):248.0 #Correct:2537 #Trained:5001 Training Accuracy:50.7%
# Progress:31.2% Speed(reviews/sec):240.6 #Correct:3787 #Trained:7501 Training Accuracy:50.4%
# Progress:41.6% Speed(reviews/sec):234.1 #Correct:5037 #Trained:10001 Training Accuracy:50.3%
# Progress:52.0% Speed(reviews/sec):226.1 #Correct:6289 #Trained:12501 Training Accuracy:50.3%
# Progress:62.5% Speed(reviews/sec):220.7 #Correct:7614 #Trained:15001 Training Accuracy:50.7%
# Progress:72.9% Speed(reviews/sec):217.4 #Correct:9064 #Trained:17501 Training Accuracy:51.7%
# Progress:83.3% Speed(reviews/sec):214.5 #Correct:10696 #Trained:20001 Training Accuracy:53.4%
# Progress:93.7% Speed(reviews/sec):212.7 #Correct:12367 #Trained:22501 Training Accuracy:54.9%
# Progress:99.9% Speed(reviews/sec):211.7 #Correct:13405 #Trained:24000 Training Accuracy:55.8%

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize))

p.scatter(x="x1", y="x2", size=8, source=source,color=colors_list)

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
